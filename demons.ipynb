# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %%
from bs4 import BeautifulSoup
# The "requests" library makes working with HTTP requests easier
# than the built-in urllib libraries.
import requests

# %%
# here we access the webpage and download the content using requests
t1970=requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")
t1970
# Out:
# <Response [200]>

# %%
# We'll just reuse the request object that was previously created to create a BeautifulSoup element.
soup = BeautifulSoup(t1970.text, "html.parser")

# In this line we are looking for a single "table" element with a class of wikitable;
# and then looking for all the "tr" elements on that table (notice the find vs find_all calls).
rows = soup.find("table", attrs={"class": "wikitable"}).find_all("tr")[1:]

# We then define a function whose job it is to act on
# each column's element in each row in the table.
def cleaner(r):
    ranking = int(r[0].get_text())
    title = r[1].get_text()
    band_singer = r[2].get_text()
    url = r[2].find("a").get("href")
    return [ranking, title, band_singer, url]


# Next we'll create a list of names that will be used as dictionary keys.
fields = ["ranking", "title", "band_singer", "url"]

# We now use the cleaner function to process each "td" element on a given row.
# It gives us a bunch of band information
# The zip function creates a list of pairs; which the dict function then uses
# to create a dictionary, using the first element of the pair as the key and the second as
# the value; and finally, the list comprehension iterates over each row element, and puts
# the result of each iteration on a list, which is then bound to the songs variable.
songs = [dict(zip(fields, cleaner(row.find_all("td")))) for row in rows]

# %%
songs[2:4]
# Out:
# [{'band_singer': 'The Guess Who\n',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas\n',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %%
#your code here
years=range(1970, 2019)
print(years)
yearstext={}
for y in years:
    print(y)
    yreq=requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_%i" % y)
    yearstext[y]=yreq.text
    time.sleep(1)
# Out:
# range(1970, 2019)
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    
"""

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %%
# your code here

fields = ["ranking", "song", "songurl", "titletext", "band_singer", "url"]

# Helper functions.
def get_cols(row):
    return row.find_all("th") + row.find_all("td")

def break_a(col):
    return list(map(list, zip(*[(a.get("title").strip('"'), a.get("href")) for a in col.find_all("a")]))) \
            or [[col.get_text().strip('"')], [None]]
    
def parse_cols(cols):
    return [int(cols[0].get_text())] + break_a(cols[1]) + [cols[1].get_text()] + break_a(cols[2])

def create_dict(cols):
    return dict(zip(fields, cols))

# Parser function.
def parse_year(year, yearstext):
    soup = BeautifulSoup(yearstext[year], 'html.parser')
    rows = soup.find("table", attrs={"class": "wikitable"}).find_all("tr")[1:]
    return [create_dict(parse_cols(get_cols(row))) for row in rows]

# %%
parse_year(1997, yearstext)[:5]
# Out:
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '"Something About the Way You Look Tonight" / "Candle in the Wind 1997"',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel (singer)'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me (Jewel song)'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '"Foolish Games" / "You Were Meant for Me"',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Sean Combs', 'Faith Evans', '112 (band)'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '"I\'ll Be Missing You"',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '"Un-Break My Heart"',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Sean Combs', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '"Can\'t Nobody Hold Me Down"',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]

# %%
yearinfo = {y:parse_year(y, yearstext) for y in years}

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
fd = open("/tmp/yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# RERUN WHEN SUBMITTING
# Another way to deal with files. Has the advantage of closing the file for you.
with open("/tmp/yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %%
fd
yearinfo
# Out:
# {'1970': [{'band_singer': ['Simon & Garfunkel'],
#    'ranking': 1,
#    'song': ['Bridge Over Troubled Water (song)'],
#    'songurl': ['/wiki/Bridge_Over_Troubled_Water_(song)'],
#    'titletext': '"Bridge Over Troubled Water"',
#    'url': ['/wiki/Simon_%26_Garfunkel']},
#   {'band_singer': ['The Carpenters'],
#    'ranking': 2,
#    'song': ['(They Long to Be) Close to You'],
#    'songurl': ['/wiki/(They_Long_to_Be)_Close_to_You'],
#    'titletext': '"(They Long to Be) Close to You"',
#    'url': ['/wiki/The_Carpenters']},
#   {'band_singer': ['The Guess Who'],
#    'ranking': 3,
#    'song': ['American Woman'],
#    'songurl': ['/wiki/American_Woman'],
#    'titletext': '"American Woman"',
#    'url': ['/wiki/The_Guess_Who']},
#   {'band_singer': ['B.J. Thomas'],
#    'ranking': 4,
#    'song': ["Raindrops Keep Fallin' on My Head"],
#    'songurl': ['/wiki/Raindrops_Keep_Fallin%27_on_My_Head'],
#    'titletext': '"Raindrops Keep Fallin\' on My Head"',
#    'url': ['/wiki/B.J._Thomas']},
#   {'band_singer': ['Edwin Starr'],
#    'ranking': 5,
#    'song': ['War (The Temptations song)'],
#    'songurl': ['/wiki/War_(The_Temptations_song)#Edwin_Starr_version'],
#    'titletext': '"War"',
#    'url': ['/wiki/Edwin_Starr']},
#   {'band_singer': ['Diana Ross'],
#    'ranking': 6,
#    'song': ["Ain't No Mountain High Enough"],
#    'songurl': ['/wiki/Ain%27t_No_Mountain_High_Enough'],
#    'titletext': '"Ain\'t No Mountain High Enough"',
#    'url': ['/wiki/Diana_Ross']},
#   {'band_singer': ['The Jackson 5'],
#    'ranking': 7,
#    'song': ["I'll Be There (The Jackson 5 song)"],
#    'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)'],
#    'titletext': '"I\'ll Be There"',
#    'url': ['/wiki/The_Jackson_5']},
#   {'band_singer': ['Rare Earth (band)'],
#    'ranking': 8,
#    'song': ['Get Ready (The Temptations song)'],
#    'songurl': ['/wiki/Get_Ready_(The_Temptations_song)#Rare_Earth_version'],
#    'titletext': '"Get Ready"',
#    'url': ['/wiki/Rare_Earth_(band)']},
#   {'band_singer': ['The Beatles'],
#    'ranking': 9,
#    'song': ['Let It Be (song)'],
#    'songurl': ['/wiki/Let_It_Be_(song)'],
#    'titletext': '"Let It Be"',
#    'url': ['/wiki/The_Beatles']},
#   {'band_singer': ['Freda Payne'],
#    'ranking': 10,
#    'song': ['Band of Gold (Freda Payne song)'],
#    'songurl': ['/wiki/Band_of_Gold_(Freda_Payne_song)'],
#    'titletext': '"Band of Gold"',
#    'url': ['/wiki/Freda_Payne']},
#   {'band_singer': ['Three Dog Night'],
#    'ranking': 11,
#    'song': ['Mama Told Me Not to Come'],
#    'songurl': ['/wiki/Mama_Told_Me_Not_to_Come'],
#    'titletext': '"Mama Told Me (Not to Come)"',
#    'url': ['/wiki/Three_Dog_Night']},
#   {'band_singer': ['Ray Stevens'],
#    'ranking': 12,
#    'song': ['Everything Is Beautiful'],
#    'songurl': ['/wiki/Everything_Is_Beautiful'],
#    'titletext': '"Everything Is Beautiful"',
#    'url': ['/wiki/Ray_Stevens']},
#   {'band_singer': ['Bread (band)'],
#    'ranking': 13,
#    'song': ['Make It with You'],
#    'songurl': ['/wiki/Make_It_with_You'],
#    'titletext': '"Make It with You"',
#    'url': ['/wiki/Bread_(band)']},
#   {'band_singer': ['Vanity Fare'],
#    'ranking': 14,
#    'song': ["Hitchin' a Ride (Vanity Fare song)"],
#    'songurl': ['/wiki/Hitchin%27_a_Ride_(Vanity_Fare_song)'],
#    'titletext': '"Hitchin\' a Ride"',
#    'url': ['/wiki/Vanity_Fare']},
#   {'band_singer': ['The Jackson 5'],
#    'ranking': 15,
#    'song': ['ABC (The Jackson 5 song)'],
#    'songurl': ['/wiki/ABC_(The_Jackson_5_song)'],
#    'titletext': '"ABC"',
#    'url': ['/wiki/The_Jackson_5']},
#   {'band_singer': ['The Jackson 5'],
#    'ranking': 16,
#    'song': ['The Love You Save'],
#    'songurl': ['/wiki/The_Love_You_Save'],
#    'titletext': '"The Love You Save"',
#    'url': ['/wiki/The_Jackson_5']},
#   {'band_singer': ['Neil Diamond'],
#    'ranking': 17,
#    'song': ["Cracklin' Rosie"],
#    'songurl': ['/wiki/Cracklin%27_Rosie'],
#    'titletext': '"Cracklin\' Rosie"',
#    'url': ['/wiki/Neil_Diamond']},
#   {'band_singer': ['Tony Orlando and Dawn'],
#    'ranking': 18,
#    'song': ['Candida (song)'],
#    'songurl': ['/wiki/Candida_(song)'],
#    'titletext': '"Candida"',
#    'url': ['/wiki/Tony_Orlando_and_Dawn']},
#   {'band_singer': ['Sly & the Family Stone'],
#    'ranking': 19,
#    'song': ['Thank You (Falettinme Be Mice Elf Agin)'],
#    'songurl': ['/wiki/Thank_You_(Falettinme_Be_Mice_Elf_Agin)'],
#    'titletext': '"Thank You (Falettinme Be Mice Elf Agin)"',
#    'url': ['/wiki/Sly_%26_the_Family_Stone']},
#   {'band_singer': ['Eric Burdon', 'War (U.S. band)'],
#    'ranking': 20,
#    'song': ['Spill the Wine'],
#    'songurl': ['/wiki/Spill_the_Wine'],
#    'titletext': '"Spill the Wine"',
#    'url': ['/wiki/Eric_Burdon', '/wiki/War_(U.S._band)']},
#   {'band_singer': ['Five Stairsteps'],
#    'ranking': 21,
#    'song': ['O-o-h Child'],
#    'songurl': ['/wiki/O-o-h_Child'],
#    'titletext': '"O-o-h Child"',
#    'url': ['/wiki/Five_Stairsteps']},
#   {'band_singer': ['Norman Greenbaum'],
#    'ranking': 22,
#    'song': ['Spirit in the Sky'],
#    'songurl': ['/wiki/Spirit_in_the_Sky'],
#    'titletext': '"Spirit in the Sky"',
#    'url': ['/wiki/Norman_Greenbaum']},
#   {'band_singer': ['Melanie Safka'],
#    'ranking': 23,
#    'song': ['Lay Down (Candles in the Rain)'],
#    'songurl': ['/wiki/Lay_Down_(Candles_in_the_Rain)'],
#    'titletext': '"Lay Down (Candles in the Rain)"',
#    'url': ['/wiki/Melanie_Safka']},
#   {'band_singer': ['The Temptations'],
#    'ranking': 24,
#    'song': ["Ball of Confusion (That's What the World Is Today)"],
#    'songurl': ['/wiki/Ball_of_Confusion_(That%27s_What_the_World_Is_Today)'],
#    'titletext': '"Ball of Confusion (That\'s What the World Is Today)"',
#    'url': ['/wiki/The_Temptations']},
#   {'band_singer': ['Ray, Goodman & Brown'],
#    'ranking': 25,
#    'song': ['Love on a Two-Way Street'],
#    'songurl': ['/wiki/Love_on_a_Two-Way_Street'],
#    'titletext': '"Love on a Two-Way Street"',
#    'url': ['/wiki/Ray,_Goodman_%26_Brown']},
#   {'band_singer': ['The Poppy Family'],
#    'ranking': 26,
#    'song': ["Which Way You Goin' Billy? (song)"],
#    'songurl': ['/wiki/Which_Way_You_Goin%27_Billy%3F_(song)'],
#    'titletext': '"Which Way You Goin\' Billy?"',
#    'url': ['/wiki/The_Poppy_Family']},
#   {'band_singer': ['Free (band)'],
#    'ranking': 27,
#    'song': ['All Right Now'],
#    'songurl': ['/wiki/All_Right_Now'],
#    'titletext': '"All Right Now"',
#    'url': ['/wiki/Free_(band)']},
#   {'band_singer': ['The Jackson 5'],
#    'ranking': 28,
#    'song': ['I Want You Back'],
#    'songurl': ['/wiki/I_Want_You_Back'],
#    'titletext': '"I Want You Back"',
#    'url': ['/wiki/The_Jackson_5']},
#   {'band_singer': ['Bobby Sherman'],
#    'ranking': 29,
#    'song': ['Julie, Do Ya Love Me'],
#    'songurl': ['/wiki/Julie,_Do_Ya_Love_Me'],
#    'titletext': '"Julie, Do Ya Love Me"',
#    'url': ['/wiki/Bobby_Sherman']},
#   {'band_singer': ['Sugarloaf (band)'],
#    'ranking': 30,
#    'song': ['Green-Eyed Lady'],
#    'songurl': ['/wiki/Green-Eyed_Lady'],
#    'titletext': '"Green-Eyed Lady"',
#    'url': ['/wiki/Sugarloaf_(band)']},
#   {'band_singer': ['Stevie Wonder'],
#    'ranking': 31,
#    'song': ["Signed, Sealed, Delivered I'm Yours"],
#    'songurl': ['/wiki/Signed,_Sealed,_Delivered_I%27m_Yours'],
#    'titletext': '"Signed, Sealed, Delivered I\'m Yours"',
#    'url': ['/wiki/Stevie_Wonder']},
#   {'band_singer': ['Blues Image'],
#    'ranking': 32,
#    'song': ['Ride Captain Ride'],
#    'songurl': ['/wiki/Ride_Captain_Ride'],
#    'titletext': '"Ride Captain Ride"',
#    'url': ['/wiki/Blues_Image']},
#   {'band_singer': ['Shocking Blue'],
#    'ranking': 33,
#    'song': ['Venus (Shocking Blue song)'],
#    'songurl': ['/wiki/Venus_(Shocking_Blue_song)'],
#    'titletext': '"Venus"',
#    'url': ['/wiki/Shocking_Blue']},
#   {'band_singer': ['John Lennon'],
#    'ranking': 34,
#    'song': ['Instant Karma!'],
#    'songurl': ['/wiki/Instant_Karma!'],
#    'titletext': '"Instant Karma!"',
#    'url': ['/wiki/John_Lennon']},
#   {'band_singer': ['Clarence Carter'],
#    'ranking': 35,
#    'song': ['Patches (Chairmen of the Board song)'],
#    'songurl': ['/wiki/Patches_(Chairmen_of_the_Board_song)'],
#    'titletext': '"Patches"',
#    'url': ['/wiki/Clarence_Carter']},
#   {'band_singer': ['Creedence Clearwater Revival'],
#    'ranking': 36,
#    'song': ["Lookin' out My Back Door"],
#    'songurl': ['/wiki/Lookin%27_out_My_Back_Door'],
#    'titletext': '"Lookin\' out My Back Door"',
#    'url': ['/wiki/Creedence_Clearwater_Revival']},
#   {'band_singer': ['Brook Benton'],
#    'ranking': 37,
#    'song': ['Rainy Night in Georgia'],
#    'songurl': ['/wiki/Rainy_Night_in_Georgia'],
#    'titletext': '"Rainy Night in Georgia"',
#    'url': ['/wiki/Brook_Benton']},
#   {'band_singer': ['Kenny Rogers', 'The First Edition (band)'],
#    'ranking': 38,
#    'song': ["Something's Burning (song)"],
#    'songurl': ['/wiki/Something%27s_Burning_(song)'],
#    'titletext': '"Something\'s Burning"',
#    'url': ['/wiki/Kenny_Rogers', '/wiki/The_First_Edition_(band)']},
#   {'band_singer': ['Chairmen of the Board'],
#    'ranking': 39,
#    'song': ['Give Me Just a Little More Time'],
#    'songurl': ['/wiki/Give_Me_Just_a_Little_More_Time'],
#    'titletext': '"Give Me Just a Little More Time"',
#    'url': ['/wiki/Chairmen_of_the_Board']},
#   {'band_singer': ['Edison Lighthouse'],
#    'ranking': 40,
#    'song': ['Love Grows (Where My Rosemary Goes)'],
#    'songurl': ['/wiki/Love_Grows_(Where_My_Rosemary_Goes)'],
#    'titletext': '"Love Grows (Where My Rosemary Goes)"',
#    'url': ['/wiki/Edison_Lighthouse']},
#   {'band_singer': ['The Beatles'],
#    'ranking': 41,
#    'song': ['The Long and Winding Road'],
#    'songurl': ['/wiki/The_Long_and_Winding_Road'],
#    'titletext': '"The Long and Winding Road"',
#    'url': ['/wiki/The_Beatles']},
#   {'band_singer': ['Anne Murray'],
#    'ranking': 42,
#    'song': ['Snowbird (song)'],
#    'songurl': ['/wiki/Snowbird_(song)'],
#    'titletext': '"Snowbird"',
#    'url': ['/wiki/Anne_Murray']},
#   {'band_singer': ['Marmalade (band)'],
#    'ranking': 43,
#    'song': ['Reflections of My Life'],
#    'songurl': ['/wiki/Reflections_of_My_Life'],
#    'titletext': '"Reflections of My Life"',
#    'url': ['/wiki/Marmalade_(band)']},
#   {'band_singer': ['Eddie Holman'],
#    'ranking': 44,
#    'song': ['Hey There Lonely Girl'],
#    'songurl': ['/wiki/Hey_There_Lonely_Girl'],
#    'titletext': '"Hey There Lonely Girl"',
#    'url': ['/wiki/Eddie_Holman']},
#   {'band_singer': ['The Jaggerz'],
#    'ranking': 45,
#    'song': ['The Rapper'],
#    'songurl': ['/wiki/The_Rapper'],
#    'titletext': '"The Rapper"',
#    'url': ['/wiki/The_Jaggerz']},
#   {'band_singer': ['The Hollies'],
#    'ranking': 46,
#    'song': ["He Ain't Heavy, He's My Brother"],
#    'songurl': ['/wiki/He_Ain%27t_Heavy,_He%27s_My_Brother'],
#    'titletext': '"He Ain\'t Heavy, He\'s My Brother"',
#    'url': ['/wiki/The_Hollies']},
#   {'band_singer': ["Alive N Kickin'"],
#    'ranking': 47,
#    'song': ['Tighter, Tighter'],
#    'songurl': ['/wiki/Tighter,_Tighter'],
#    'titletext': '"Tighter, Tighter"',
#    'url': ['/wiki/Alive_N_Kickin%27']},
#   {'band_singer': ['Badfinger'],
#    'ranking': 48,
#    'song': ['Come and Get It (Badfinger song)'],
#    'songurl': ['/wiki/Come_and_Get_It_(Badfinger_song)'],
#    'titletext': '"Come and Get It"',
#    'url': ['/wiki/Badfinger']},
#   {'band_singer': ['Simon & Garfunkel'],
#    'ranking': 49,
#    'song': ['Cecilia (Simon & Garfunkel song)'],
#    'songurl': ['/wiki/Cecilia_(Simon_%26_Garfunkel_song)'],
#    'titletext': '"Cecilia"',
#    'url': ['/wiki/Simon_%26_Garfunkel']},
#   {'band_singer': ['Charles Wright & the Watts 103rd Street Rhythm Band'],
#    'ranking': 50,
#    'song': ['Love Land (song)'],
#    'songurl': ['/wiki/Love_Land_(song)'],
#    'titletext': '"Love Land"',
#    'url': ['/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band']},
#   {'band_singer': ['Tyrone Davis'],
#    'ranking': 51,
#    'song': ['Turn Back the Hands of Time (song)'],
#    'songurl': ['/wiki/Turn_Back_the_Hands_of_Time_(song)'],
#    'titletext': '"Turn Back the Hands of Time"',
#    'url': ['/wiki/Tyrone_Davis']},
#   {'band_singer': ['The Kinks'],
#    'ranking': 52,
#    'song': ['Lola (song)'],
#    'songurl': ['/wiki/Lola_(song)'],
#    'titletext': '"Lola"',
#    'url': ['/wiki/The_Kinks']},
#   {'band_singer': ['Mungo Jerry'],
#    'ranking': 53,
#    'song': ['In the Summertime (Mungo Jerry song)'],
#    'songurl': ['/wiki/In_the_Summertime_(Mungo_Jerry_song)'],
#    'titletext': '"In the Summertime"',
#    'url': ['/wiki/Mungo_Jerry']},
#   {'band_singer': ['R. Dean Taylor'],
#    'ranking': 54,
#    'song': ['Indiana Wants Me'],
#    'songurl': ['/wiki/Indiana_Wants_Me'],
#    'titletext': '"Indiana Wants Me"',
#    'url': ['/wiki/R._Dean_Taylor']},
#   {'band_singer': ['Rare Earth (band)'],
#    'ranking': 55,
#    'song': ["(I Know) I'm Losing You"],
#    'songurl': ['/wiki/(I_Know)_I%27m_Losing_You'],
#    'titletext': '"(I Know) I\'m Losing You"',
#    'url': ['/wiki/Rare_Earth_(band)']},
#   {'band_singer': ['Bobby Sherman'],
#    'ranking': 56,
#    'song': ['Easy Come, Easy Go (Bobby Sherman song)'],
#    'songurl': ['/wiki/Easy_Come,_Easy_Go_(Bobby_Sherman_song)'],
#    'titletext': '"Easy Come, Easy Go"',
#    'url': ['/wiki/Bobby_Sherman']},
#   {'band_singer': ['Charles Wright & the Watts 103rd Street Rhythm Band'],
#    'ranking': 57,
#    'song': ['Express Yourself (Charles Wright & the Watts 103rd Street Rhythm Band song)'],
#    'songurl': ['/wiki/Express_Yourself_(Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band_song)'],
#    'titletext': '"Express Yourself"',
#    'url': ['/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band']},
#   {'band_singer': ['The Four Tops'],
#    'ranking': 58,
#    'song': ['Still Water (Love)'],
#    'songurl': ['/wiki/Still_Water_(Love)'],
#    'titletext': '"Still Water (Love)"',
#    'url': ['/wiki/The_Four_Tops']},
#   {'band_singer': ['Chicago (band)'],
#    'ranking': 59,
#    'song': ['Make Me Smile'],
#    'songurl': ['/wiki/Make_Me_Smile'],
#    'titletext': '"Make Me Smile"',
#    'url': ['/wiki/Chicago_(band)']},
#   {'band_singer': ['Frijid Pink'],
#    'ranking': 60,
#    'song': ['The House of the Rising Sun'],
#    'songurl': ['/wiki/The_House_of_the_Rising_Sun'],
#    'titletext': '"The House of the Rising Sun"',
#    'url': ['/wiki/Frijid_Pink']},
#   {'band_singer': ['Chicago (band)'],
#    'ranking': 61,
#    'song': ['25 or 6 to 4'],
#    'songurl': ['/wiki/25_or_6_to_4'],
#    'titletext': '"25 or 6 to 4"',
#    'url': ['/wiki/Chicago_(band)']},
#   {'band_singer': ['White Plains (band)'],
#    'ranking': 62,
#    'song': ["My Baby Loves Lovin'"],
#    'songurl': ['/wiki/My_Baby_Loves_Lovin%27'],
#    'titletext': '"My Baby Loves Lovin\'"',
#    'url': ['/wiki/White_Plains_(band)']},
#   {'band_singer': ['The Friends of Distinction'],
#    'ranking': 63,
#    'song': ['Love or Let Me Be Lonely'],
#    'songurl': ['/wiki/Love_or_Let_Me_Be_Lonely'],
#    'titletext': '"Love or Let Me Be Lonely"',
#    'url': ['/wiki/The_Friends_of_Distinction']},
#   {'band_singer': ['The Brotherhood of Man'],
#    'ranking': 64,
#    'song': ['United We Stand (song)'],
#    'songurl': ['/wiki/United_We_Stand_(song)'],
#    'titletext': '"United We Stand"',
#    'url': ['/wiki/The_Brotherhood_of_Man']},
#   {'band_singer': ['The Carpenters'],
#    'ranking': 65,
#    'song': ["We've Only Just Begun"],
#    'songurl': ['/wiki/We%27ve_Only_Just_Begun'],
#    'titletext': '"We\'ve Only Just Begun"',
#    'url': ['/wiki/The_Carpenters']},
#   {'band_singer': ['Mark Lindsay'],
#    'ranking': 66,
#    'song': ['Arizona (song)'],
#    'songurl': ['/wiki/Arizona_(song)'],
#    'titletext': '"Arizona"',
#    'url': ['/wiki/Mark_Lindsay']},
#   {'band_singer': ['James Taylor'],
#    'ranking': 67,
#    'song': ['Fire and Rain (song)'],
#    'songurl': ['/wiki/Fire_and_Rain_(song)'],
#    'titletext': '"Fire and Rain"',
#    'url': ['/wiki/James_Taylor']},
#   {'band_singer': ['Gene Chandler'],
#    'ranking': 68,
#    'song': ['Groovy Situation'],
#    'songurl': ['/wiki/Groovy_Situation'],
#    'titletext': '"Groovy Situation"',
#    'url': ['/wiki/Gene_Chandler']},
#   {'band_singer': ['Santana (band)'],
#    'ranking': 69,
#    'song': ['Evil Ways'],
#    'songurl': ['/wiki/Evil_Ways'],
#    'titletext': '"Evil Ways"',
#    'url': ['/wiki/Santana_(band)']},
#   {'band_singer': ['The Guess Who'],
#    'ranking': 70,
#    'song': ['No Time (The Guess Who song)'],
#    'songurl': ['/wiki/No_Time_(The_Guess_Who_song)'],
#    'titletext': '"No Time"',
#    'url': ['/wiki/The_Guess_Who']},
#   {'band_singer': ['The Delfonics'],
#    'ranking': 71,
#    'song': ["Didn't I (Blow Your Mind This Time)"],
#    'songurl': ['/wiki/Didn%27t_I_(Blow_Your_Mind_This_Time)'],
#    'titletext': '"Didn\'t I (Blow Your Mind This Time)"',
#    'url': ['/wiki/The_Delfonics']},
#   {'band_singer': ['Elvis Presley'],
#    'ranking': 72,
#    'song': ['The Wonder of You'],
#    'songurl': ['/wiki/The_Wonder_of_You'],
#    'titletext': '"The Wonder of You"',
#    'url': ['/wiki/Elvis_Presley']},
#   {'band_singer': ['Creedence Clearwater Revival'],
#    'ranking': 73,
#    'song': ['Up Around the Bend'],
#    'songurl': ['/wiki/Up_Around_the_Bend'],
#    'titletext': '"Up Around the Bend"',
#    'url': ['/wiki/Creedence_Clearwater_Revival']},
#   {'band_singer': ['Ronnie Dyson'],
#    'ranking': 74,
#    'song': ["(If You Let Me Make Love To You Then) Why Can't I Touch You?"],
#    'songurl': ['/wiki/(If_You_Let_Me_Make_Love_To_You_Then)_Why_Can%27t_I_Touch_You%3F'],
#    'titletext': '"(If You Let Me Make Love To You Then) Why Can\'t I Touch You?"',
#    'url': ['/wiki/Ronnie_Dyson']},
#   {'band_singer': ['B.J. Thomas'],
#    'ranking': 75,
#    'song': ["I Just Can't Help Believing"],
#    'songurl': ['/wiki/I_Just_Can%27t_Help_Believing'],
#    'titletext': '"I Just Can\'t Help Believing"',
#    'url': ['/wiki/B.J._Thomas']},
#   {'band_singer': ['The Spinners (American band)'],
#    'ranking': 76,
#    'song': ["It's a Shame (The Spinners song)"],
#    'songurl': ['/wiki/It%27s_a_Shame_(The_Spinners_song)'],
#    'titletext': '"It\'s a Shame"',
#    'url': ['/wiki/The_Spinners_(American_band)']},
#   {'band_singer': ['Bobbi Martin'],
#    'ranking': 77,
#    'song': ['For the Love of Him'],
#    'songurl': ['/wiki/For_the_Love_of_Him'],
#    'titletext': '"For the Love of Him"',
#    'url': ['/wiki/Bobbi_Martin']},
#   {'band_singer': ['Mountain (band)'],
#    'ranking': 78,
#    'song': ['Mississippi Queen'],
#    'songurl': ['/wiki/Mississippi_Queen'],
#    'titletext': '"Mississippi Queen"',
#    'url': ['/wiki/Mountain_(band)']},
#   {'band_singer': ['Ike & Tina Turner'],
#    'ranking': 79,
#    'song': ['I Want to Take You Higher'],
#    'songurl': ['/wiki/I_Want_to_Take_You_Higher'],
#    'titletext': '"I Want to Take You Higher"',
#    'url': ['/wiki/Ike_%26_Tina_Turner']},
#   {'band_singer': ['Joe Cocker'],
#    'ranking': 80,
#    'song': ['The Letter (The Box Tops song)'],
#    'songurl': ['/wiki/The_Letter_(The_Box_Tops_song)'],
#    'titletext': '"The Letter"',
#    'url': ['/wiki/Joe_Cocker']},
#   {'band_singer': ['Tee Set'],
#    'ranking': 81,
#    'song': ['Ma Belle Amie'],
#    'songurl': ['/wiki/Ma_Belle_Amie'],
#    'titletext': '"Ma Belle Amie"',
#    'url': ['/wiki/Tee_Set']},
#   {'band_singer': ['The Originals (band)'],
#    'ranking': 82,
#    'song': ['The Bells (The Originals song)'],
#    'songurl': ['/wiki/The_Bells_(The_Originals_song)'],
#    'titletext': '"The Bells"',
#    'url': ['/wiki/The_Originals_(band)']},
#   {'band_singer': ['Christie (band)'],
#    'ranking': 83,
#    'song': ['Yellow River (song)'],
#    'songurl': ['/wiki/Yellow_River_(song)'],
#    'titletext': '"Yellow River"',
#    'url': ['/wiki/Christie_(band)']},
#   {'band_singer': ['100 Proof (Aged in Soul)'],
#    'ranking': 84,
#    'song': ["Somebody's Been Sleeping"],
#    'songurl': ['/wiki/Somebody%27s_Been_Sleeping'],
#    'titletext': '"Somebody\'s Been Sleeping"',
#    'url': ['/wiki/100_Proof_(Aged_in_Soul)']},
#   {'band_singer': ['The Ides of March (band)'],
#    'ranking': 85,
#    'song': ['Vehicle (song)'],
#    'songurl': ['/wiki/Vehicle_(song)'],
#    'titletext': '"Vehicle"',
#    'url': ['/wiki/The_Ides_of_March_(band)']},
#   {'band_singer': ['The Pipkins'],
#    'ranking': 86,
#    'song': ['Gimme Dat Ding (song)'],
#    'songurl': ['/wiki/Gimme_Dat_Ding_(song)'],
#    'titletext': '"Gimme Dat Ding"',
#    'url': ['/wiki/The_Pipkins']},
#   {'band_singer': ['Robin McNamara'],
#    'ranking': 87,
#    'song': ["Lay a Little Lovin' on Me"],
#    'songurl': ['/wiki/Lay_a_Little_Lovin%27_on_Me'],
#    'titletext': '"Lay a Little Lovin\' on Me"',
#    'url': ['/wiki/Robin_McNamara']},
#   {'band_singer': ['The Supremes'],
#    'ranking': 88,
#    'song': ['Up the Ladder to the Roof'],
#    'songurl': ['/wiki/Up_the_Ladder_to_the_Roof'],
#    'titletext': '"Up the Ladder to the Roof"',
#    'url': ['/wiki/The_Supremes']},
#   {'band_singer': ['Creedence Clearwater Revival'],
#    'ranking': 89,
#    'song': ["Travelin' Band"],
#    'songurl': ['/wiki/Travelin%27_Band'],
#    'titletext': '"Travelin\' Band"',
#    'url': ['/wiki/Creedence_Clearwater_Revival']},
#   {'band_singer': ['The Sandpipers'],
#    'ranking': 90,
#    'song': ['Come Saturday Morning (song)'],
#    'songurl': ['/wiki/Come_Saturday_Morning_(song)'],
#    'titletext': '"Come Saturday Morning"',
#    'url': ['/wiki/The_Sandpipers']},
#   {'band_singer': ['The Temptations'],
#    'ranking': 91,
#    'song': ['Psychedelic Shack (song)'],
#    'songurl': ['/wiki/Psychedelic_Shack_(song)'],
#    'titletext': '"Psychedelic Shack"',
#    'url': ['/wiki/The_Temptations']},
#   {'band_singer': ['Tom Jones (singer)'],
#    'ranking': 92,
#    'song': ['Without Love (There Is Nothing)'],
#    'songurl': ['/wiki/Without_Love_(There_Is_Nothing)'],
#    'titletext': '"Without Love (There Is Nothing)"',
#    'url': ['/wiki/Tom_Jones_(singer)']},
#   {'band_singer': ['Pacific Gas & Electric (band)'],
#    'ranking': 93,
#    'song': ['Are You Ready? (Pacific Gas & Electric song)'],
#    'songurl': ['/wiki/Are_You_Ready%3F_(Pacific_Gas_%26_Electric_song)'],
#    'titletext': '"Are You Ready?"',
#    'url': ['/wiki/Pacific_Gas_%26_Electric_(band)']},
#   {'band_singer': ['Crosby, Stills, Nash & Young'],
#    'ranking': 94,
#    'song': ['Woodstock (song)'],
#    'songurl': ['/wiki/Woodstock_(song)'],
#    'titletext': '"Woodstock"',
#    'url': ['/wiki/Crosby,_Stills,_Nash_%26_Young']},
#   {'band_singer': ['Dionne Warwick'],
#    'ranking': 95,
#    'song': ["I'll Never Fall in Love Again"],
#    'songurl': ['/wiki/I%27ll_Never_Fall_in_Love_Again'],
#    'titletext': '"I\'ll Never Fall in Love Again"',
#    'url': ['/wiki/Dionne_Warwick']},
#   {'band_singer': ['The New Seekers'],
#    'ranking': 96,
#    'song': ["Look What They've Done to My Song Ma"],
#    'songurl': ['/wiki/Look_What_They%27ve_Done_to_My_Song_Ma'],
#    'titletext': '"Look What They\'ve Done to My Song Ma"',
#    'url': ['/wiki/The_New_Seekers']},
#   {'band_singer': ['Joe South'],
#    'ranking': 97,
#    'song': ['Walk A Mile In My Shoes'],
#    'songurl': ['/wiki/Walk_A_Mile_In_My_Shoes'],
#    'titletext': '"Walk A Mile In My Shoes"',
#    'url': ['/wiki/Joe_South']},
#   {'band_singer': ['B.B. King'],
#    'ranking': 98,
#    'song': ['The Thrill Is Gone (1951 song)'],
#    'songurl': ['/wiki/The_Thrill_Is_Gone_(1951_song)'],
#    'titletext': '"The Thrill Is Gone"',
#    'url': ['/wiki/B.B._King']},
#   {'band_singer': ['Glen Campbell'],
#    'ranking': 99,
#    'song': ["It's Only Make Believe"],
#    'songurl': ['/wiki/It%27s_Only_Make_Believe'],
#    'titletext': '"It\'s Only Make Believe"',
#    'url': ['/wiki/Glen_Campbell']},
#   {'band_singer': ['Aretha Franklin'],
#    'ranking': 100,
#    'song': ['Call Me (Aretha Franklin song)'],
#    'songurl': ['/wiki/Call_Me_(Aretha_Franklin_song)'],
#    'titletext': '"Call Me"',
#    'url': ['/wiki/Aretha_Franklin']}],
#  '1971': [{'band_singer': ['Three Dog Night'],
#    'ranking': 1,
#    'song': ['Joy to the World (Hoyt Axton song)'],
#    'songurl': ['/wiki/Joy_to_the_World_(Hoyt_Axton_song)'],
#    'titletext': '"Joy to the World"',
#    'url': ['/wiki/Three_Dog_Night']},
#   {'band_singer': ['Rod Stewart'],
#    'ranking': 2,
#    'song': ['Maggie May', 'Reason to Believe'],
#    'songurl': ['/wiki/Maggie_May', '/wiki/Reason_to_Believe'],
#    'titletext': '"Maggie May"/"Reason to Believe"',
#    'url': ['/wiki/Rod_Stewart']},
#   {'band_singer': ['Carole King'],
#    'ranking': 3,
#    'song': ["It's Too Late (Carole King song)", 'I Feel the Earth Move'],
#    'songurl': ['/wiki/It%27s_Too_Late_(Carole_King_song)',
#     '/wiki/I_Feel_the_Earth_Move'],
#    'titletext': '"It\'s Too Late"/"I Feel the Earth Move"',
#    'url': ['/wiki/Carole_King']},
#   {'band_singer': ['The Osmonds'],
#    'ranking': 4,
#    'song': ['One Bad Apple'],
#    'songurl': ['/wiki/One_Bad_Apple'],
#    'titletext': '"One Bad Apple"',
#    'url': ['/wiki/The_Osmonds']},
#   {'band_singer': ['Bee Gees'],
#    'ranking': 5,
#    'song': ['How Can You Mend a Broken Heart'],
#    'songurl': ['/wiki/How_Can_You_Mend_a_Broken_Heart'],
#    'titletext': '"How Can You Mend a Broken Heart"',
#    'url': ['/wiki/Bee_Gees']},
#   {'band_singer': ['Paul Revere & the Raiders'],
#    'ranking': 6,
#    'song': ['Indian Reservation (The Lament of the Cherokee Reservation Indian)'],
#    'songurl': ['/wiki/Indian_Reservation_(The_Lament_of_the_Cherokee_Reservation_Indian)'],
#    'titletext': '"Indian Reservation (The Lament of the Cherokee Reservation Indian)"',
#    'url': ['/wiki/Paul_Revere_%26_the_Raiders']},
#   {'band_singer': ['Donny Osmond'],
#    'ranking': 7,
#    'song': ['Go Away Little Girl'],
#    'songurl': ['/wiki/Go_Away_Little_Girl'],
#    'titletext': '"Go Away Little Girl"',
#    'url': ['/wiki/Donny_Osmond']},
#   {'band_singer': ['John Denver'],
#    'ranking': 8,
#    'song': ['Take Me Home, Country Roads'],
#    'songurl': ['/wiki/Take_Me_Home,_Country_Roads'],
#    'titletext': '"Take Me Home, Country Roads"',
#    'url': ['/wiki/John_Denver']},
#   {'band_singer': ['The Temptations'],
#    'ranking': 9,
#    'song': ['Just My Imagination (Running Away with Me)'],
#    'songurl': ['/wiki/Just_My_Imagination_(Running_Away_with_Me)'],
#    'titletext': '"Just My Imagination (Running Away with Me)"',
#    'url': ['/wiki/The_Temptations']},
#   {'band_singer': ['Tony Orlando and Dawn'],
#    'ranking': 10,
#    'song': ['Knock Three Times'],
#    'songurl': ['/wiki/Knock_Three_Times'],
#    'titletext': '"Knock Three Times"',
#    'url': ['/wiki/Tony_Orlando_and_Dawn']},
#   {'band_singer': ['Janis Joplin'],
#    'ranking': 11,
#    'song': ['Me and Bobby McGee'],
#    'songurl': ['/wiki/Me_and_Bobby_McGee'],
#    'titletext': '"Me and Bobby McGee"',
#    'url': ['/wiki/Janis_Joplin']},
#   {'band_singer': ['Al Green'],
#    'ranking': 12,
#    'song': ['Tired of Being Alone'],
#    'songurl': ['/wiki/Tired_of_Being_Alone'],
#    'titletext': '"Tired of Being Alone"',
#    'url': ['/wiki/Al_Green']},
#   {'band_singer': ['Honey Cone'],
#    'ranking': 13,
#    'song': ['Want Ads'],
#    'songurl': ['/wiki/Want_Ads'],
#    'titletext': '"Want Ads"',
#    'url': ['/wiki/Honey_Cone']},
#   {'band_singer': ['The Undisputed Truth'],
#    'ranking': 14,
#    'song': ['Smiling Faces Sometimes'],
#    'songurl': ['/wiki/Smiling_Faces_Sometimes'],
#    'titletext': '"Smiling Faces Sometimes"',
#    'url': ['/wiki/The_Undisputed_Truth']},
#   {'band_singer': ['Cornelius Brothers & Sister Rose'],
#    'ranking': 15,
#    'song': ['Treat Her Like a Lady (Cornelius Brothers & Sister Rose song)'],
#    'songurl': ['/wiki/Treat_Her_Like_a_Lady_(Cornelius_Brothers_%26_Sister_Rose_song)'],
#    'titletext': '"Treat Her Like a Lady"',
#    'url': ['/wiki/Cornelius_Brothers_%26_Sister_Rose']},
#   {'band_singer': ['James Taylor'],
#    'ranking': 16,
#    'song': ["You've Got a Friend"],
#    'songurl': ['/wiki/You%27ve_Got_a_Friend'],
#    'titletext': '"You\'ve Got a Friend"',
#    'url': ['/wiki/James_Taylor']},
#   {'band_singer': ['Jean Knight'],
#    'ranking': 17,
#    'song': ['Mr. Big Stuff'],
#    'songurl': ['/wiki/Mr._Big_Stuff'],
#    'titletext': '"Mr. Big Stuff"',
#    'url': ['/wiki/Jean_Knight']},
#   {'band_singer': ['The Rolling Stones'],
#    'ranking': 18,
#    'song': ['Brown Sugar (song)'],
#    'songurl': ['/wiki/Brown_Sugar_(song)'],
#    'titletext': '"Brown Sugar"',
#    'url': ['/wiki/The_Rolling_Stones']},
#   {'band_singer': ['Lee Michaels'],
#    'ranking': 19,
#    'song': ['Do You Know What I Mean'],
#    'songurl': ['/wiki/Do_You_Know_What_I_Mean'],
#    'titletext': '"Do You Know What I Mean"',
#    'url': ['/wiki/Lee_Michaels']},
#   {'band_singer': ['Joan Baez'],
#    'ranking': 20,
#    'song': ['The Night They Drove Old Dixie Down'],
#    'songurl': ['/wiki/The_Night_They_Drove_Old_Dixie_Down'],
#    'titletext': '"The Night They Drove Old Dixie Down"',
#    'url': ['/wiki/Joan_Baez']},
#   {'band_singer': ['Marvin Gaye'],
#    'ranking': 21,
#    'song': ["What's Going On (song)"],
#    'songurl': ['/wiki/What%27s_Going_On_(song)'],
#    'titletext': '"What\'s Going On"',
#    'url': ['/wiki/Marvin_Gaye']},
#   {'band_singer': ['Paul McCartney', 'Linda McCartney'],
#    'ranking': 22,
#    'song': ['Uncle Albert/Admiral Halsey'],
#    'songurl': ['/wiki/Uncle_Albert/Admiral_Halsey'],
#    'titletext': '"Uncle Albert/Admiral Halsey"',
#    'url': ['/wiki/Paul_McCartney', '/wiki/Linda_McCartney']},
#   {'band_singer': ['Bill Withers'],
#    'ranking': 23,
#    'song': ["Ain't No Sunshine"],
#    'songurl': ['/wiki/Ain%27t_No_Sunshine'],
#    'titletext': '"Ain\'t No Sunshine"',
#    'url': ['/wiki/Bill_Withers']},
#   {'band_singer': ['Five Man Electrical Band'],
#    'ranking': 24,
#    'song': ['Signs (Five Man Electrical Band song)'],
#    'songurl': ['/wiki/Signs_(Five_Man_Electrical_Band_song)'],
#    'titletext': '"Signs"',
#    'url': ['/wiki/Five_Man_Electrical_Band']},
#   {'band_singer': ['Tom Jones (singer)'],
#    'ranking': 25,
#    'song': ["She's a Lady"],
#    'songurl': ['/wiki/She%27s_a_Lady'],
#    'titletext': '"She\'s a Lady"',
#    'url': ['/wiki/Tom_Jones_(singer)']},
#   {'band_singer': ['Murray Head'],
#    'ranking': 26,
#    'song': ['Superstar (Jesus Christ Superstar song)'],
#    'songurl': ['/wiki/Superstar_(Jesus_Christ_Superstar_song)'],
#    'titletext': '"Superstar"',
#    'url': ['/wiki/Murray_Head']},
#   {'band_singer': ['The Free Movement'],
#    'ranking': 27,
#    'song': ["I've Found Someone of My Own"],
#    'songurl': ['/wiki/I%27ve_Found_Someone_of_My_Own'],
#    'titletext': '"I\'ve Found Someone of My Own"',
#    'url': ['/wiki/The_Free_Movement']},
#   {'band_singer': ['Jerry Reed'],
#    'ranking': 28,
#    'song': ['Amos Moses'],
#    'songurl': ['/wiki/Amos_Moses'],
#    'titletext': '"Amos Moses"',
#    'url': ['/wiki/Jerry_Reed']},
#   {'band_singer': ['The Grass Roots'],
#    'ranking': 29,
#    'song': ['Temptation Eyes'],
#    'songurl': ['/wiki/Temptation_Eyes'],
#    'titletext': '"Temptation Eyes"',
#    'url': ['/wiki/The_Grass_Roots']},
#   {'band_singer': ['The Carpenters'],
#    'ranking': 30,
#    'song': ['Superstar (Delaney and Bonnie song)'],
#    'songurl': ['/wiki/Superstar_(Delaney_and_Bonnie_song)'],
#    'titletext': '"Superstar"',
#    'url': ['/wiki/The_Carpenters']},
#   {'band_singer': ['George Harrison'],
#    'ranking': 31,
#    'song': ['My Sweet Lord'],
#    'songurl': ['/wiki/My_Sweet_Lord'],
#    'titletext': '"My Sweet Lord"',
#    'url': ['/wiki/George_Harrison']},
#   {'band_singer': ['Donny Osmond'],
#    'ranking': 32,
#    'song': ['Sweet and Innocent (Donny Osmond song)'],
#    'songurl': ['/wiki/Sweet_and_Innocent_(Donny_Osmond_song)'],
#    'titletext': '"Sweet and Innocent"',
#    'url': ['/wiki/Donny_Osmond']},
#   {'band_singer': ['Ocean (band)'],
#    'ranking': 33,
#    'song': ['Put Your Hand in the Hand'],
#    'songurl': ['/wiki/Put_Your_Hand_in_the_Hand'],
#    'titletext': '"Put Your Hand in the Hand"',
#    'url': ['/wiki/Ocean_(band)']},
#   {'band_singer': ['Daddy Dewdrop'],
#    'ranking': 34,
#    'song': ["Chick-A-Boom (Don't Ya Jes' Love It)"],
#    'songurl': ['/wiki/Chick-A-Boom_(Don%27t_Ya_Jes%27_Love_It)'],
#    'titletext': '"Chick-A-Boom (Don\'t Ya Jes\' Love It)"',
#    'url': ['/wiki/Daddy_Dewdrop']},
#   {'band_singer': ['The Carpenters'],
#    'ranking': 35,
#    'song': ['For All We Know (1970 song)'],
#    'songurl': ['/wiki/For_All_We_Know_(1970_song)'],
#    'titletext': '"For All We Know"',
#    'url': ['/wiki/The_Carpenters']},
#   {'band_singer': ['Sammi Smith'],
#    'ranking': 36,
#    'song': ['Help Me Make It Through the Night'],
#    'songurl': ['/wiki/Help_Me_Make_It_Through_the_Night'],
#    'titletext': '"Help Me Make It Through the Night"',
#    'url': ['/wiki/Sammi_Smith']},
#   {'band_singer': ['The Carpenters'],
#    'ranking': 37,
#    'song': ['Rainy Days and Mondays'],
#    'songurl': ['/wiki/Rainy_Days_and_Mondays'],
#    'titletext': '"Rainy Days and Mondays"',
#    'url': ['/wiki/The_Carpenters']},
#   {'band_singer': ['Gordon Lightfoot'],
#    'ranking': 38,
#    'song': ['If You Could Read My Mind'],
#    'songurl': ['/wiki/If_You_Could_Read_My_Mind'],
#    'titletext': '"If You Could Read My Mind"',
#    'url': ['/wiki/Gordon_Lightfoot']},
#   {'band_singer': ['Cher'],
#    'ranking': 39,
#    'song': ['Gypsys, Tramps & Thieves'],
#    'songurl': ['/wiki/Gypsys,_Tramps_%26_Thieves'],
#    'titletext': '"Gypsys, Tramps & Thieves"',
#    'url': ['/wiki/Cher']},
#   {'band_singer': ['The Jackson 5'],
#    'ranking': 40,
#    'song': ['Never Can Say Goodbye'],
#    'songurl': ['/wiki/Never_Can_Say_Goodbye'],
#    'titletext': '"Never Can Say Goodbye"',
#    'url': ['/wiki/The_Jackson_5']},
#   {'band_singer': ['Lynn Anderson'],
#    'ranking': 41,
#    'song': ['Rose Garden (Lynn Anderson song)'],
#    'songurl': ['/wiki/Rose_Garden_(Lynn_Anderson_song)'],
#    'titletext': '"Rose Garden"',
#    'url': ['/wiki/Lynn_Anderson']},
#   {'band_singer': ['Hamilton, Joe Frank & Reynolds'],
#    'ranking': 42,
#    'song': ["Don't Pull Your Love"],
#    'songurl': ['/wiki/Don%27t_Pull_Your_Love'],
#    'titletext': '"Don\'t Pull Your Love"',
#    'url': ['/wiki/Hamilton,_Joe_Frank_%26_Reynolds']},
#   {'band_singer': ['Ringo Starr'],
#    'ranking': 43,
#    'song': ["It Don't Come Easy"],
#    'songurl': ['/wiki/It_Don%27t_Come_Easy'],
#    'titletext': '"It Don\'t Come Easy"',
#    'url': ['/wiki/Ringo_Starr']},
#   {'band_singer': ['Nitty Gritty Dirt Band'],
#    'ranking': 44,
#    'song': ['Mr. Bojangles (song)'],
#    'songurl': ['/wiki/Mr._Bojangles_(song)'],
#    'titletext': '"Mr. Bojangles"',
#    'url': ['/wiki/Nitty_Gritty_Dirt_Band']},
#   {'band_singer': ['The Fuzz (band)'],
#    'ranking': 45,
#    'song': ['I Love You for All Seasons'],
#    'songurl': ['/wiki/I_Love_You_for_All_Seasons'],
#    'titletext': '"I Love You for All Seasons"',
#    'url': ['/wiki/The_Fuzz_(band)']},
#   {'band_singer': ['The Dramatics'],
#    'ranking': 46,
#    'song': ['Whatcha See is Whatcha Get (song)'],
#    'songurl': ['/wiki/Whatcha_See_is_Whatcha_Get_(song)'],
#    'titletext': '"Whatcha See is Whatcha Get"',
#    'url': ['/wiki/The_Dramatics']},
#   {'band_singer': ['Carly Simon'],
#    'ranking': 47,
#    'song': ["That's the Way I've Always Heard It Should Be"],
#    'songurl': ['/wiki/That%27s_the_Way_I%27ve_Always_Heard_It_Should_Be'],
#    'titletext': '"That\'s the Way I\'ve Always Heard It Should Be"',
#    'url': ['/wiki/Carly_Simon']},
#   {'band_singer': ['Stevie Wonder'],
#    'ranking': 48,
#    'song': ['If You Really Love Me'],
#    'songurl': ['/wiki/If_You_Really_Love_Me'],
#    'titletext': '"If You Really Love Me"',
#    'url': ['/wiki/Stevie_Wonder']},
#   {'band_singer': ['Aretha Franklin'],
#    'ranking': 49,
#    'song': ['Spanish Harlem (song)'],
#    'songurl': ['/wiki/Spanish_Harlem_(song)'],
#    'titletext': '"Spanish Harlem"',
#    'url': ['/wiki/Aretha_Franklin']},
#   {'band_singer': ['Helen Reddy'],
#    'ranking': 50,
#    'song': ["I Don't Know How to Love Him"],
#    'songurl': ['/wiki/I_Don%27t_Know_How_to_Love_Him'],
#    'titletext': '"I Don\'t Know How to Love Him"',
#    'url': ['/wiki/Helen_Reddy']},
#   {'band_singer': ['The Osmonds'],
#    'ranking': 51,
#    'song': ['Yo-Yo (Billy Joe Royal song)'],
#    'songurl': ['/wiki/Yo-Yo_(Billy_Joe_Royal_song)'],
#    'titletext': '"Yo-Yo"',
#    'url': ['/wiki/The_Osmonds']},
#   {'band_singer': ['Aretha Franklin'],
#    'ranking': 52,
#    'song': ['Bridge over Troubled Water (song)'],
#    'songurl': ['/wiki/Bridge_over_Troubled_Water_(song)'],
#    'titletext': '"Bridge over Troubled Water"',
#    'url': ['/wiki/Aretha_Franklin']},
#   {'band_singer': ['The Partridge Family'],
#    'ranking': 53,
#    'song': ["Doesn't Somebody Want to Be Wanted"],
#    'songurl': ['/wiki/Doesn%27t_Somebody_Want_to_Be_Wanted'],
#    'titletext': '"Doesn\'t Somebody Want to Be Wanted"',
#    'url': ['/wiki/The_Partridge_Family']},
#   {'band_singer': ['Tommy James'],
#    'ranking': 54,
#    'song': ["Draggin' the Line"],
#    'songurl': ['/wiki/Draggin%27_the_Line'],
#    'titletext': '"Draggin\' the Line"',
#    'url': ['/wiki/Tommy_James']},
#   {'band_singer': ['Ike & Tina Turner'],
#    'ranking': 55,
#    'song': ['Proud Mary'],
#    'songurl': ['/wiki/Proud_Mary'],
#    'titletext': '"Proud Mary"',
#    'url': ['/wiki/Ike_%26_Tina_Turner']},
#   {'band_singer': ['Chicago (band)'],
#    'ranking': 56,
#    'song': ['Beginnings (Chicago song)', 'Colour My World (Chicago song)'],
#    'songurl': ['/wiki/Beginnings_(Chicago_song)',
#     '/wiki/Colour_My_World_(Chicago_song)'],
#    'titletext': '"Beginnings"/"Colour My World"',
#    'url': ['/wiki/Chicago_(band)']},
#   {'band_singer': ['The Bells (band)'],
#    'ranking': 57,
#    'song': ['Stay Awhile (The Bells song)'],
#    'songurl': ['/wiki/Stay_Awhile_(The_Bells_song)'],
#    'titletext': '"Stay Awhile"',
#    'url': ['/wiki/The_Bells_(band)']},
#   {'band_singer': ['The Stampeders'],
#    'ranking': 58,
#    'song': ['Sweet City Woman'],
#    'songurl': ['/wiki/Sweet_City_Woman'],
#    'titletext': '"Sweet City Woman"',
#    'url': ['/wiki/The_Stampeders']},
#   {'band_singer': ['Lobo (musician)'],
#    'ranking': 59,
#    'song': ['Me and You and a Dog Named Boo'],
#    'songurl': ['/wiki/Me_and_You_and_a_Dog_Named_Boo'],
#    'titletext': '"Me and You and a Dog Named Boo"',
#    'url': ['/wiki/Lobo_(musician)']},
#   {'band_singer': ['Paul McCartney'],
#    'ranking': 60,
#    'song': ['Another Day (Paul McCartney song)', 'Oh Woman, Oh Why'],
#    'songurl': ['/wiki/Another_Day_(Paul_McCartney_song)',
#     '/wiki/Oh_Woman,_Oh_Why'],
#    'titletext': '"Another Day"/"Oh Woman, Oh Why"',
#    'url': ['/wiki/Paul_McCartney']},
#   {'band_singer': ['Bread (band)'],
#    'ranking': 61,
#    'song': ['If (Bread song)'],
#    'songurl': ['/wiki/If_(Bread_song)'],
#    'titletext': '"If"',
#    'url': ['/wiki/Bread_(band)']},
#   {'band_singer': ['Marvin Gaye'],
#    'ranking': 62,
#    'song': ['Mercy Mercy Me (The Ecology)'],
#    'songurl': ['/wiki/Mercy_Mercy_Me_(The_Ecology)'],
#    'titletext': '"Mercy Mercy Me (The Ecology)"',
#    'url': ['/wiki/Marvin_Gaye']},
#   {'band_singer': ['Brewer & Shipley'],
#    'ranking': 63,
#    'song': ['One Toke Over the Line'],
#    'songurl': [None],
#    'titletext': '"One Toke Over the Line"',
#    'url': ['/wiki/Brewer_%26_Shipley']},
#   {'band_singer': ['8th Day (R&B group)'],
#    'ranking': 64,
#    'song': ["She's Not Just Another Woman"],
#    'songurl': [None],
#    'titletext': '"She\'s Not Just Another Woman"',
#    'url': ['/wiki/8th_Day_(R%26B_group)']},
#   {'band_singer': ['Freda Payne'],
#    'ranking': 65,
#    'song': ['Bring the Boys Home'],
#    'songurl': ['/wiki/Bring_the_Boys_Home'],
#    'titletext': '"Bring the Boys Home"',
#    'url': ['/wiki/Freda_Payne']},
#   {'band_singer': ['Rare Earth (band)'],
#    'ranking': 66,
#    'song': ['I Just Want to Celebrate'],
#    'songurl': ['/wiki/I_Just_Want_to_Celebrate'],
#    'titletext': '"I Just Want to Celebrate"',
#    'url': ['/wiki/Rare_Earth_(band)']},
#   {'band_singer': ['Delaney & Bonnie'],
#    'ranking': 67,
#    'song': ['Never Ending Song of Love'],
#    'songurl': ['/wiki/Never_Ending_Song_of_Love'],
#    'titletext': '"Never Ending Song of Love"',
#    'url': ['/wiki/Delaney_%26_Bonnie']},
#   {'band_singer': ['Freddie Hart (musician)'],
#    'ranking': 68,
#    'song': ['Easy Loving'],
#    'songurl': ['/wiki/Easy_Loving'],
#    'titletext': '"Easy Loving"',
#    'url': ['/wiki/Freddie_Hart_(musician)']},
#   {'band_singer': ['Three Dog Night'],
#    'ranking': 69,
#    'song': ['Liar (Russ Ballard song)'],
#    'songurl': ['/wiki/Liar_(Russ_Ballard_song)'],
#    'titletext': '"Liar"',
#    'url': ['/wiki/Three_Dog_Night']},
#   {'band_singer': ['Honey Cone'],
#    'ranking': 70,
#    'song': ['Stick-Up'],
#    'songurl': ['/wiki/Stick-Up'],
#    'titletext': '"Stick-Up"',
#    'url': ['/wiki/Honey_Cone']},
#   {'band_singer': ['Mac and Katie Kissoon'],
#    'ranking': 71,
#    'song': ['Chirpy Chirpy Cheep Cheep'],
#    'songurl': ['/wiki/Chirpy_Chirpy_Cheep_Cheep'],
#    'titletext': '"Chirpy Chirpy Cheep Cheep"',
#    'url': ['/wiki/Mac_and_Katie_Kissoon']},
#   {'band_singer': ['Andy Williams'],
#    'ranking': 72,
#    'song': ['(Where Do I Begin?) Love Story'],
#    'songurl': ['/wiki/(Where_Do_I_Begin%3F)_Love_Story'],
#    'titletext': '"(Where Do I Begin?) Love Story"',
#    'url': ['/wiki/Andy_Williams']},
#   {'band_singer': ['Cat Stevens'],
#    'ranking': 73,
#    'song': ['Wild World (song)'],
#    'songurl': ['/wiki/Wild_World_(song)'],
#    'titletext': '"Wild World"',
#    'url': ['/wiki/Cat_Stevens']},
#   {'band_singer': ['Jerry Reed'],
#    'ranking': 74,
#    'song': ["When You're Hot, You're Hot"],
#    'songurl': ['/wiki/When_You%27re_Hot,_You%27re_Hot'],
#    'titletext': '"When You\'re Hot, You\'re Hot"',
#    'url': ['/wiki/Jerry_Reed']},
#   {'band_singer': ['The Beginning of the End (band)'],
#    'ranking': 75,
#    'song': ['Funky Nassau'],
#    'songurl': ['/wiki/Funky_Nassau'],
#    'titletext': '"Funky Nassau"',
#    'url': ['/wiki/The_Beginning_of_the_End_(band)']},
#   {'band_singer': ['Olivia Newton-John'],
#    'ranking': 76,
#    'song': ['If Not for You'],
#    'songurl': ['/wiki/If_Not_for_You'],
#    'titletext': '"If Not for You"',
#    'url': ['/wiki/Olivia_Newton-John']},
#   {'band_singer': ['King Floyd'],
#    'ranking': 77,
#    'song': ['Groove Me'],
#    'songurl': ['/wiki/Groove_Me'],
#    'titletext': '"Groove Me"',
#    'url': ['/wiki/King_Floyd']},
#   {'band_singer': ['Bobby Goldsboro'],
#    'ranking': 78,
#    'song': ['Watching Scotty Grow'],
#    'songurl': ['/wiki/Watching_Scotty_Grow'],
#    'titletext': '"Watching Scotty Grow"',
#    'url': ['/wiki/Bobby_Goldsboro']},
#   {'band_singer': ['Matthews Southern Comfort'],
#    'ranking': 79,
#    'song': ['Woodstock (song)'],
#    'songurl': ['/wiki/Woodstock_(song)'],
#    'titletext': '"Woodstock"',
#    'url': ['/wiki/Matthews_Southern_Comfort']},
#   {'band_singer': ['Judy Collins'],
#    'ranking': 80,
#    'song': ['Amazing Grace'],
#    'songurl': ['/wiki/Amazing_Grace'],
#    'titletext': '"Amazing Grace"',
#    'url': ['/wiki/Judy_Collins']},
#   {'band_singer': ['Dave Edmunds'],
#    'ranking': 81,
#    'song': ['I Hear You Knocking'],
#    'songurl': ['/wiki/I_Hear_You_Knocking'],
#    'titletext': '"I Hear You Knocking"',
#    'url': ['/wiki/Dave_Edmunds']},
#   {'band_singer': ['Bee Gees'],
#    'ranking': 82,
#    'song': ['Lonely Days'],
#    'songurl': ['/wiki/Lonely_Days'],
#    'titletext': '"Lonely Days"',
#    'url': ['/wiki/Bee_Gees']},
#   {'band_singer': ['The Fortunes'],
#    'ranking': 83,
#    'song': ['Here Comes That Rainy Day Feeling Again'],
#    'songurl': ['/wiki/Here_Comes_That_Rainy_Day_Feeling_Again'],
#    'titletext': '"Here Comes That Rainy Day Feeling Again"',
#    'url': ['/wiki/The_Fortunes']},
#   {'band_singer': ['The Who'],
#    'ranking': 84,
#    'song': ["Won't Get Fooled Again"],
#    'songurl': ['/wiki/Won%27t_Get_Fooled_Again'],
#    'titletext': '"Won\'t Get Fooled Again"',
#    'url': ['/wiki/The_Who']},
#   {'band_singer': ['Denise LaSalle'],
#    'ranking': 85,
#    'song': ['Trapped By a Thing Called Love'],
#    'songurl': ['/wiki/Trapped_By_a_Thing_Called_Love'],
#    'titletext': '"Trapped By a Thing Called Love"',
#    'url': ['/wiki/Denise_LaSalle']},
#   {'band_singer': ['The Jackson 5'],
#    'ranking': 86,
#    'song': ["Mama's Pearl"],
#    'songurl': ['/wiki/Mama%27s_Pearl'],
#    'titletext': '"Mama\'s Pearl"',
#    'url': ['/wiki/The_Jackson_5']},
#   {'band_singer': ['The Buoys'],
#    'ranking': 87,
#    'song': ['Timothy (song)'],
#    'songurl': ['/wiki/Timothy_(song)'],
#    'titletext': '"Timothy"',
#    'url': ['/wiki/The_Buoys']},
#   {'band_singer': ['The Partridge Family'],
#    'ranking': 88,
#    'song': ['I Woke Up In Love This Morning'],
#    'songurl': ['/wiki/I_Woke_Up_In_Love_This_Morning'],
#    'titletext': '"I Woke Up In Love This Morning"',
#    'url': ['/wiki/The_Partridge_Family']},
#   {'band_singer': ['Isaac Hayes'],
#    'ranking': 89,
#    'song': ['Theme from Shaft'],
#    'songurl': ['/wiki/Theme_from_Shaft'],
#    'titletext': '"Theme from Shaft"',
#    'url': ['/wiki/Isaac_Hayes']},
#   {'band_singer': ['Gladys Knight & the Pips'],
#    'ranking': 90,
#    'song': ['If I Were Your Woman (song)'],
#    'songurl': ['/wiki/If_I_Were_Your_Woman_(song)'],
#    'titletext': '"If I Were Your Woman"',
#    'url': ['/wiki/Gladys_Knight_%26_the_Pips']},
#   {'band_singer': ['Neil Diamond'],
#    'ranking': 91,
#    'song': ['I Am...I Said'],
#    'songurl': ['/wiki/I_Am...I_Said'],
#    'titletext': '"I Am...I Said"',
#    'url': ['/wiki/Neil_Diamond']},
#   {'band_singer': ['Paul Stookey'],
#    'ranking': 92,
#    'song': ['The Wedding Song (There Is Love)'],
#    'songurl': ['/wiki/The_Wedding_Song_(There_Is_Love)'],
#    'titletext': '"The Wedding Song (There Is Love)"',
#    'url': ['/wiki/Paul_Stookey']},
#   {'band_singer': ['Wilson Pickett'],
#    'ranking': 93,
#    'song': ["Don't Knock My Love"],
#    'songurl': ['/wiki/Don%27t_Knock_My_Love'],
#    'titletext': '"Don\'t Knock My Love"',
#    'url': ['/wiki/Wilson_Pickett']},
#   {'band_singer': ['The Doors'],
#    'ranking': 94,
#    'song': ['Love Her Madly'],
#    'songurl': ['/wiki/Love_Her_Madly'],
#    'titletext': '"Love Her Madly"',
#    'url': ['/wiki/The_Doors']},
#   {'band_singer': ['Richie Havens'],
#    'ranking': 95,
#    'song': ['Here Comes the Sun'],
#    'songurl': ['/wiki/Here_Comes_the_Sun'],
#    'titletext': '"Here Comes the Sun"',
#    'url': ['/wiki/Richie_Havens']},
#   {'band_singer': ['Wadsworth Mansion (band)'],
#    'ranking': 96,
#    'song': ['Sweet Mary'],
#    'songurl': [None],
#    'titletext': '"Sweet Mary"',
#    'url': ['/wiki/Wadsworth_Mansion_(band)']},
#   {'band_singer': ['Brenda & the Tabulations'],
#    'ranking': 97,
#    'song': ['Right on the Tip of My Tongue'],
#    'songurl': [None],
#    'titletext': '"Right on the Tip of My Tongue"',
#    'url': ['/wiki/Brenda_%26_the_Tabulations']},
#   {'band_singer': ['The 5th Dimension'],
#    'ranking': 98,
#    'song': ['One Less Bell to Answer'],
#    'songurl': ['/wiki/One_Less_Bell_to_Answer'],
#    'titletext': '"One Less Bell to Answer"',
#    'url': ['/wiki/The_5th_Dimension']},
#   {'band_singer': ['The Doors'],
#    'ranking': 99,
#    'song': ['Riders on the Storm'],
#    'songurl': ['/wiki/Riders_on_the_Storm'],
#    'titletext': '"Riders on the Storm"',
#    'url': ['/wiki/The_Doors']},
#   {'band_singer': ['Perry Como'],
#    'ranking': 100,
#    'song': ["Somos Novios (It's Impossible)"],
#    'songurl': ['/wiki/Somos_Novios_(It%27s_Impossible)'],
#    'titletext': '"Somos Novios (It\'s Impossible)"',
#    'url': ['/wiki/Perry_Como']}],
#  '1972': [{'band_singer': ['Roberta Flack'],
#    'ranking': 1,
#    'song': ['The First Time Ever I Saw Your Face'],
#    'songurl': ['/wiki/The_First_Time_Ever_I_Saw_Your_Face'],
#    'titletext': '"The First Time Ever I Saw Your Face"',
#    'url': ['/wiki/Roberta_Flack']},
#   {'band_singer': ["Gilbert O'Sullivan"],
#    'ranking': 2,
#    'song': ['Alone Again (Naturally)'],
#    'songurl': ['/wiki/Alone_Again_(Naturally)'],
#    'titletext': '"Alone Again (Naturally)"',
#    'url': ['/wiki/Gilbert_O%27Sullivan']},
#   {'band_singer': ['Don McLean'],
#    'ranking': 3,
#    'song': ['American Pie (song)'],
#    'songurl': ['/wiki/American_Pie_(song)'],
#    'titletext': '"American Pie"',
#    'url': ['/wiki/Don_McLean']},
#   {'band_singer': ['Harry Nilsson'],
#    'ranking': 4,
#    'song': ['Without You (Badfinger song)'],
#    'songurl': ['/wiki/Without_You_(Badfinger_song)'],
#    'titletext': '"Without You"',
#    'url': ['/wiki/Harry_Nilsson']},
#   {'band_singer': ['Sammy Davis Jr.'],
#    'ranking': 5,
#    'song': ['The Candy Man'],
#    'songurl': ['/wiki/The_Candy_Man'],
#    'titletext': '"The Candy Man"',
#    'url': ['/wiki/Sammy_Davis_Jr.']},
#   {'band_singer': ['Joe Tex'],
#    'ranking': 6,
#    'song': ['I Gotcha (Joe Tex song)'],
#    'songurl': ['/wiki/I_Gotcha_(Joe_Tex_song)'],
#    'titletext': '"I Gotcha"',
#    'url': ['/wiki/Joe_Tex']},
#   {'band_singer': ['Bill Withers'],
#    'ranking': 7,
#    'song': ['Lean on Me (song)'],
#    'songurl': ['/wiki/Lean_on_Me_(song)'],
#    'titletext': '"Lean on Me"',
#    'url': ['/wiki/Bill_Withers']},
#   {'band_singer': ['Mac Davis'],
#    'ranking': 8,
#    'song': ["Baby, Don't Get Hooked on Me"],
#    'songurl': ['/wiki/Baby,_Don%27t_Get_Hooked_on_Me'],
#    'titletext': '"Baby, Don\'t Get Hooked on Me"',
#    'url': ['/wiki/Mac_Davis']},
#   {'band_singer': ['Melanie Safka'],
#    'ranking': 9,
#    'song': ['Brand New Key'],
#    'songurl': ['/wiki/Brand_New_Key'],
# ...
#    'url': ['/wiki/G-Eazy', '/wiki/ASAP_Rocky', '/wiki/Cardi_B']},
#   {'band_singer': ['6ix9ine', 'Nicki Minaj', 'Murda Beatz'],
#    'ranking': 31,
#    'song': ['Fefe (song)'],
#    'songurl': ['/wiki/Fefe_(song)'],
#    'titletext': '"Fefe"',
#    'url': ['/wiki/6ix9ine', '/wiki/Nicki_Minaj', '/wiki/Murda_Beatz']},
#   {'band_singer': ['Dan + Shay'],
#    'ranking': 32,
#    'song': ['Tequila (Dan + Shay song)'],
#    'songurl': ['/wiki/Tequila_(Dan_%2B_Shay_song)'],
#    'titletext': '"Tequila"',
#    'url': ['/wiki/Dan_%2B_Shay']},
#   {'band_singer': ['Portugal. The Man'],
#    'ranking': 33,
#    'song': ['Feel It Still'],
#    'songurl': ['/wiki/Feel_It_Still'],
#    'titletext': '"Feel It Still"',
#    'url': ['/wiki/Portugal._The_Man']},
#   {'band_singer': ['Migos', 'Nicki Minaj', 'Cardi B'],
#    'ranking': 34,
#    'song': ['MotorSport'],
#    'songurl': ['/wiki/MotorSport'],
#    'titletext': '"MotorSport"',
#    'url': ['/wiki/Migos', '/wiki/Nicki_Minaj', '/wiki/Cardi_B']},
#   {'band_singer': ['Lauv'],
#    'ranking': 35,
#    'song': ['I Like Me Better'],
#    'songurl': ['/wiki/I_Like_Me_Better'],
#    'titletext': '"I Like Me Better"',
#    'url': ['/wiki/Lauv']},
#   {'band_singer': ['5 Seconds of Summer'],
#    'ranking': 36,
#    'song': ['Youngblood (5 Seconds of Summer song)'],
#    'songurl': ['/wiki/Youngblood_(5_Seconds_of_Summer_song)'],
#    'titletext': '"Youngblood"',
#    'url': ['/wiki/5_Seconds_of_Summer']},
#   {'band_singer': ['Imagine Dragons'],
#    'ranking': 37,
#    'song': ['Whatever It Takes (Imagine Dragons song)'],
#    'songurl': ['/wiki/Whatever_It_Takes_(Imagine_Dragons_song)'],
#    'titletext': '"Whatever It Takes"',
#    'url': ['/wiki/Imagine_Dragons']},
#   {'band_singer': ['Offset (rapper)', 'Metro Boomin'],
#    'ranking': 38,
#    'song': ['Ric Flair Drip'],
#    'songurl': ['/wiki/Ric_Flair_Drip'],
#    'titletext': '"Ric Flair Drip"',
#    'url': ['/wiki/Offset_(rapper)', '/wiki/Metro_Boomin']},
#   {'band_singer': ['Post Malone'],
#    'ranking': 39,
#    'song': ['I Fall Apart'],
#    'songurl': ['/wiki/I_Fall_Apart'],
#    'titletext': '"I Fall Apart"',
#    'url': ['/wiki/Post_Malone']},
#   {'band_singer': ['The Weeknd', 'Kendrick Lamar'],
#    'ranking': 40,
#    'song': ['Pray for Me (The Weeknd and Kendrick Lamar song)'],
#    'songurl': ['/wiki/Pray_for_Me_(The_Weeknd_and_Kendrick_Lamar_song)'],
#    'titletext': '"Pray for Me"',
#    'url': ['/wiki/The_Weeknd', '/wiki/Kendrick_Lamar']},
#   {'band_singer': ['Selena Gomez'],
#    'ranking': 41,
#    'song': ['Back to You (Selena Gomez song)'],
#    'songurl': ['/wiki/Back_to_You_(Selena_Gomez_song)'],
#    'titletext': '"Back to You"',
#    'url': ['/wiki/Selena_Gomez']},
#   {'band_singer': ['Travis Scott'],
#    'ranking': 42,
#    'song': ['Sicko Mode'],
#    'songurl': ['/wiki/Sicko_Mode'],
#    'titletext': '"Sicko Mode"',
#    'url': ['/wiki/Travis_Scott']},
#   {'band_singer': ['Migos', 'Drake (musician)'],
#    'ranking': 43,
#    'song': ['Walk It Talk It'],
#    'songurl': ['/wiki/Walk_It_Talk_It'],
#    'titletext': '"Walk It Talk It"',
#    'url': ['/wiki/Migos', '/wiki/Drake_(musician)']},
#   {'band_singer': ['Lil Pump'],
#    'ranking': 44,
#    'song': ['Gucci Gang'],
#    'songurl': ['/wiki/Gucci_Gang'],
#    'titletext': '"Gucci Gang"',
#    'url': ['/wiki/Lil_Pump']},
#   {'band_singer': ['G-Eazy', 'Halsey (singer)'],
#    'ranking': 45,
#    'song': ['Him & I'],
#    'songurl': ['/wiki/Him_%26_I'],
#    'titletext': '"Him & I"',
#    'url': ['/wiki/G-Eazy', '/wiki/Halsey_(singer)']},
#   {'band_singer': ['Shawn Mendes'],
#    'ranking': 46,
#    'song': ['In My Blood (Shawn Mendes song)'],
#    'songurl': ['/wiki/In_My_Blood_(Shawn_Mendes_song)'],
#    'titletext': '"In My Blood"',
#    'url': ['/wiki/Shawn_Mendes']},
#   {'band_singer': ['Kendrick Lamar', 'SZA (singer)'],
#    'ranking': 47,
#    'song': ['All the Stars'],
#    'songurl': ['/wiki/All_the_Stars'],
#    'titletext': '"All the Stars"',
#    'url': ['/wiki/Kendrick_Lamar', '/wiki/SZA_(singer)']},
#   {'band_singer': ['Migos'],
#    'ranking': 48,
#    'song': ['Stir Fry (song)'],
#    'songurl': ['/wiki/Stir_Fry_(song)'],
#    'titletext': '"Stir Fry"',
#    'url': ['/wiki/Migos']},
#   {'band_singer': ['Sam Smith (singer)'],
#    'ranking': 49,
#    'song': ['Too Good at Goodbyes'],
#    'songurl': ['/wiki/Too_Good_at_Goodbyes'],
#    'titletext': '"Too Good at Goodbyes"',
#    'url': ['/wiki/Sam_Smith_(singer)']},
#   {'band_singer': ['Kendrick Lamar'],
#    'ranking': 50,
#    'song': ['Love (Kendrick Lamar song)'],
#    'songurl': ['/wiki/Love_(Kendrick_Lamar_song)'],
#    'titletext': '"Love"',
#    'url': ['/wiki/Kendrick_Lamar']},
#   {'band_singer': ['Donald Glover'],
#    'ranking': 51,
#    'song': ['This Is America (song)'],
#    'songurl': ['/wiki/This_Is_America_(song)'],
#    'titletext': '"This Is America"',
#    'url': ['/wiki/Donald_Glover']},
#   {'band_singer': ['Drake (musician)'],
#    'ranking': 52,
#    'song': ['Nonstop (song)'],
#    'songurl': ['/wiki/Nonstop_(song)'],
#    'titletext': '"Nonstop"',
#    'url': ['/wiki/Drake_(musician)']},
#   {'band_singer': ['Kane Brown'],
#    'ranking': 53,
#    'song': ['Heaven (Kane Brown song)'],
#    'songurl': ['/wiki/Heaven_(Kane_Brown_song)'],
#    'titletext': '"Heaven"',
#    'url': ['/wiki/Kane_Brown']},
#   {'band_singer': ['Cardi B'],
#    'ranking': 54,
#    'song': ['Bodak Yellow'],
#    'songurl': ['/wiki/Bodak_Yellow'],
#    'titletext': '"Bodak Yellow"',
#    'url': ['/wiki/Cardi_B']},
#   {'band_singer': ['Lil Dicky', 'Chris Brown'],
#    'ranking': 55,
#    'song': ['Freaky Friday (song)'],
#    'songurl': ['/wiki/Freaky_Friday_(song)'],
#    'titletext': '"Freaky Friday"',
#    'url': ['/wiki/Lil_Dicky', '/wiki/Chris_Brown']},
#   {'band_singer': ['6ix9ine'],
#    'ranking': 56,
#    'song': ['Gummo (song)'],
#    'songurl': ['/wiki/Gummo_(song)'],
#    'titletext': '"Gummo"',
#    'url': ['/wiki/6ix9ine']},
#   {'band_singer': ['Rich the Kid'],
#    'ranking': 57,
#    'song': ['Plug Walk'],
#    'songurl': ['/wiki/Plug_Walk'],
#    'titletext': '"Plug Walk"',
#    'url': ['/wiki/Rich_the_Kid']},
#   {'band_singer': ['Maroon 5'],
#    'ranking': 58,
#    'song': ['Wait (Maroon 5 song)'],
#    'songurl': ['/wiki/Wait_(Maroon_5_song)'],
#    'titletext': '"Wait"',
#    'url': ['/wiki/Maroon_5']},
#   {'band_singer': ['Cardi B'],
#    'ranking': 59,
#    'song': ['Be Careful (Cardi B song)'],
#    'songurl': ['/wiki/Be_Careful_(Cardi_B_song)'],
#    'titletext': '"Be Careful"',
#    'url': ['/wiki/Cardi_B']},
#   {'band_singer': ['Selena Gomez', 'Marshmello'],
#    'ranking': 60,
#    'song': ['Wolves (Selena Gomez and Marshmello song)'],
#    'songurl': ['/wiki/Wolves_(Selena_Gomez_and_Marshmello_song)'],
#    'titletext': '"Wolves"',
#    'url': ['/wiki/Selena_Gomez', '/wiki/Marshmello']},
#   {'band_singer': ['Cardi B', '21 Savage'],
#    'ranking': 61,
#    'song': ['Bartier Cardi'],
#    'songurl': ['/wiki/Bartier_Cardi'],
#    'titletext': '"Bartier Cardi"',
#    'url': ['/wiki/Cardi_B', '/wiki/21_Savage']},
#   {'band_singer': ['Ariana Grande'],
#    'ranking': 62,
#    'song': ['God Is a Woman'],
#    'songurl': ['/wiki/God_Is_a_Woman'],
#    'titletext': '"God Is a Woman"',
#    'url': ['/wiki/Ariana_Grande']},
#   {'band_singer': ['YG (rapper)', '2 Chainz', 'Nicki Minaj', 'Big Sean'],
#    'ranking': 63,
#    'song': ['Big Bank'],
#    'songurl': ['/wiki/Big_Bank'],
#    'titletext': '"Big Bank"',
#    'url': ['/wiki/YG_(rapper)',
#     '/wiki/2_Chainz',
#     '/wiki/Nicki_Minaj',
#     '/wiki/Big_Sean']},
#   {'band_singer': ['Demi Lovato'],
#    'ranking': 64,
#    'song': ['Sorry Not Sorry (Demi Lovato song)'],
#    'songurl': ['/wiki/Sorry_Not_Sorry_(Demi_Lovato_song)'],
#    'titletext': '"Sorry Not Sorry"',
#    'url': ['/wiki/Demi_Lovato']},
#   {'band_singer': ['Charlie Puth'],
#    'ranking': 65,
#    'song': ['How Long (Charlie Puth song)'],
#    'songurl': ['/wiki/How_Long_(Charlie_Puth_song)'],
#    'titletext': '"How Long"',
#    'url': ['/wiki/Charlie_Puth']},
#   {'band_singer': ['Max Schneider', 'Gnash (musician)'],
#    'ranking': 66,
#    'song': ['Lights Down Low (Max song)'],
#    'songurl': ['/wiki/Lights_Down_Low_(Max_song)'],
#    'titletext': '"Lights Down Low"',
#    'url': ['/wiki/Max_Schneider', '/wiki/Gnash_(musician)']},
#   {'band_singer': ['Khalid (singer)'],
#    'ranking': 67,
#    'song': ['Young Dumb & Broke'],
#    'songurl': ['/wiki/Young_Dumb_%26_Broke'],
#    'titletext': '"Young Dumb & Broke"',
#    'url': ['/wiki/Khalid_(singer)']},
#   {'band_singer': ['Calvin Harris', 'Dua Lipa'],
#    'ranking': 68,
#    'song': ['One Kiss (song)'],
#    'songurl': ['/wiki/One_Kiss_(song)'],
#    'titletext': '"One Kiss"',
#    'url': ['/wiki/Calvin_Harris', '/wiki/Dua_Lipa']},
#   {'band_singer': ['Imagine Dragons'],
#    'ranking': 69,
#    'song': ['Natural (Imagine Dragons song)'],
#    'songurl': ['/wiki/Natural_(Imagine_Dragons_song)'],
#    'titletext': '"Natural"',
#    'url': ['/wiki/Imagine_Dragons']},
#   {'band_singer': ['Jason Aldean'],
#    'ranking': 70,
#    'song': ['You Make It Easy'],
#    'songurl': ['/wiki/You_Make_It_Easy'],
#    'titletext': '"You Make It Easy"',
#    'url': ['/wiki/Jason_Aldean']},
#   {'band_singer': ['Ed Sheeran'],
#    'ranking': 71,
#    'song': ['Shape of You'],
#    'songurl': ['/wiki/Shape_of_You'],
#    'titletext': '"Shape of You"',
#    'url': ['/wiki/Ed_Sheeran']},
#   {'band_singer': ['Gucci Mane', 'Migos'],
#    'ranking': 72,
#    'song': ['I Get the Bag'],
#    'songurl': ['/wiki/I_Get_the_Bag'],
#    'titletext': '"I Get the Bag"',
#    'url': ['/wiki/Gucci_Mane', '/wiki/Migos']},
#   {'band_singer': ['DJ Khaled', 'Justin Bieber', 'Chance the Rapper', 'Quavo'],
#    'ranking': 73,
#    'song': ['No Brainer (song)'],
#    'songurl': ['/wiki/No_Brainer_(song)'],
#    'titletext': '"No Brainer"',
#    'url': ['/wiki/DJ_Khaled',
#     '/wiki/Justin_Bieber',
#     '/wiki/Chance_the_Rapper',
#     '/wiki/Quavo']},
#   {'band_singer': ['ASAP Ferg', 'Nicki Minaj'],
#    'ranking': 74,
#    'song': ['Plain Jane (song)'],
#    'songurl': ['/wiki/Plain_Jane_(song)'],
#    'titletext': '"Plain Jane"',
#    'url': ['/wiki/ASAP_Ferg', '/wiki/Nicki_Minaj']},
#   {'band_singer': ['Miguel (singer)', 'Travis Scott'],
#    'ranking': 75,
#    'song': ['Sky Walker (song)'],
#    'songurl': ['/wiki/Sky_Walker_(song)'],
#    'titletext': '"Sky Walker"',
#    'url': ['/wiki/Miguel_(singer)', '/wiki/Travis_Scott']},
#   {'band_singer': ['Thomas Rhett'],
#    'ranking': 76,
#    'song': ['Marry Me (Thomas Rhett song)'],
#    'songurl': ['/wiki/Marry_Me_(Thomas_Rhett_song)'],
#    'titletext': '"Marry Me"',
#    'url': ['/wiki/Thomas_Rhett']},
#   {'band_singer': ['Benny Blanco', 'Halsey (singer)', 'Khalid (singer)'],
#    'ranking': 77,
#    'song': ['Eastside (song)'],
#    'songurl': ['/wiki/Eastside_(song)'],
#    'titletext': '"Eastside"',
#    'url': ['/wiki/Benny_Blanco',
#     '/wiki/Halsey_(singer)',
#     '/wiki/Khalid_(singer)']},
#   {'band_singer': ['The Weeknd'],
#    'ranking': 78,
#    'song': ['Call Out My Name'],
#    'songurl': ['/wiki/Call_Out_My_Name'],
#    'titletext': '"Call Out My Name"',
#    'url': ['/wiki/The_Weeknd']},
#   {'band_singer': ['Jay Rock',
#     'Kendrick Lamar',
#     'Future (rapper)',
#     'James Blake (musician)'],
#    'ranking': 79,
#    'song': ["King's Dead"],
#    'songurl': ['/wiki/King%27s_Dead'],
#    'titletext': '"King\'s Dead"',
#    'url': ['/wiki/Jay_Rock',
#     '/wiki/Kendrick_Lamar',
#     '/wiki/Future_(rapper)',
#     '/wiki/James_Blake_(musician)']},
#   {'band_singer': ['Marshmello', 'Bastille (band)'],
#    'ranking': 80,
#    'song': ['Happier (Marshmello and Bastille song)'],
#    'songurl': ['/wiki/Happier_(Marshmello_and_Bastille_song)'],
#    'titletext': '"Happier"',
#    'url': ['/wiki/Marshmello', '/wiki/Bastille_(band)']},
#   {'band_singer': ['Bad Bunny', 'Nicky Jam', 'Ozuna (singer)'],
#    'ranking': 81,
#    'song': ['Te Boté'],
#    'songurl': ['/wiki/Te_Bot%C3%A9'],
#    'titletext': '"Te Boté"',
#    'url': ['/wiki/Bad_Bunny', '/wiki/Nicky_Jam', '/wiki/Ozuna_(singer)']},
#   {'band_singer': ['Florida Georgia Line'],
#    'ranking': 82,
#    'song': ['Simple (Florida Georgia Line song)'],
#    'songurl': ['/wiki/Simple_(Florida_Georgia_Line_song)'],
#    'titletext': '"Simple"',
#    'url': ['/wiki/Florida_Georgia_Line']},
#   {'band_singer': ['N.E.R.D', 'Rihanna'],
#    'ranking': 83,
#    'song': ['Lemon (N.E.R.D and Rihanna song)'],
#    'songurl': ['/wiki/Lemon_(N.E.R.D_and_Rihanna_song)'],
#    'titletext': '"Lemon"',
#    'url': ['/wiki/N.E.R.D', '/wiki/Rihanna']},
#   {'band_singer': ['Logic (musician)', 'Alessia Cara', 'Khalid (singer)'],
#    'ranking': 84,
#    'song': ['1-800-273-8255 (song)'],
#    'songurl': ['/wiki/1-800-273-8255_(song)'],
#    'titletext': '"1-800-273-8255"',
#    'url': ['/wiki/Logic_(musician)',
#     '/wiki/Alessia_Cara',
#     '/wiki/Khalid_(singer)']},
#   {'band_singer': ['Justin Timberlake', 'Chris Stapleton'],
#    'ranking': 85,
#    'song': ['Say Something (Justin Timberlake song)'],
#    'songurl': ['/wiki/Say_Something_(Justin_Timberlake_song)'],
#    'titletext': '"Say Something"',
#    'url': ['/wiki/Justin_Timberlake', '/wiki/Chris_Stapleton']},
#   {'band_singer': ['Drake (musician)'],
#    'ranking': 86,
#    'song': ["I'm Upset"],
#    'songurl': ['/wiki/I%27m_Upset'],
#    'titletext': '"I\'m Upset"',
#    'url': ['/wiki/Drake_(musician)']},
#   {'band_singer': ['Kenny Chesney'],
#    'ranking': 87,
#    'song': ['Get Along (Kenny Chesney song)'],
#    'songurl': ['/wiki/Get_Along_(Kenny_Chesney_song)'],
#    'titletext': '"Get Along"',
#    'url': ['/wiki/Kenny_Chesney']},
#   {'band_singer': ['XXXTentacion'],
#    'ranking': 88,
#    'song': ['Moonlight (XXXTentacion song)'],
#    'songurl': ['/wiki/Moonlight_(XXXTentacion_song)'],
#    'titletext': '"Moonlight"',
#    'url': ['/wiki/XXXTentacion']},
#   {'band_singer': ['Maroon 5', 'SZA (singer)'],
#    'ranking': 89,
#    'song': ['What Lovers Do'],
#    'songurl': ['/wiki/What_Lovers_Do'],
#    'titletext': '"What Lovers Do"',
#    'url': ['/wiki/Maroon_5', '/wiki/SZA_(singer)']},
#   {'band_singer': ['Nicky Jam', 'J Balvin'],
#    'ranking': 90,
#    'song': ['X (Nicky Jam and J Balvin song)'],
#    'songurl': ['/wiki/X_(Nicky_Jam_and_J_Balvin_song)'],
#    'titletext': '"X"',
#    'url': ['/wiki/Nicky_Jam', '/wiki/J_Balvin']},
#   {'band_singer': ['YoungBoy Never Broke Again'],
#    'ranking': 91,
#    'song': ['Outside Today'],
#    'songurl': ['/wiki/Outside_Today'],
#    'titletext': '"Outside Today"',
#    'url': ['/wiki/YoungBoy_Never_Broke_Again']},
#   {'band_singer': ['Ella Mai'],
#    'ranking': 92,
#    'song': ['Trip (Ella Mai song)'],
#    'songurl': ['/wiki/Trip_(Ella_Mai_song)'],
#    'titletext': '"Trip"',
#    'url': ['/wiki/Ella_Mai']},
#   {'band_singer': ['Daddy Yankee'],
#    'ranking': 93,
#    'song': ['Dura (song)'],
#    'songurl': ['/wiki/Dura_(song)'],
#    'titletext': '"Dura"',
#    'url': ['/wiki/Daddy_Yankee']},
#   {'band_singer': ['XXXTentacion'],
#    'ranking': 94,
#    'song': ['Changes (XXXTentacion song)'],
#    'songurl': ['/wiki/Changes_(XXXTentacion_song)'],
#    'titletext': '"Changes"',
#    'url': ['/wiki/XXXTentacion']},
#   {'band_singer': ['Brett Young (singer)'],
#    'ranking': 95,
#    'song': ['Mercy (Brett Young song)'],
#    'songurl': ['/wiki/Mercy_(Brett_Young_song)'],
#    'titletext': '"Mercy"',
#    'url': ['/wiki/Brett_Young_(singer)']},
#   {'band_singer': ['Luke Combs'],
#    'ranking': 96,
#    'song': ['One Number Away'],
#    'songurl': ['/wiki/One_Number_Away'],
#    'titletext': '"One Number Away"',
#    'url': ['/wiki/Luke_Combs']},
#   {'band_singer': ['Rae Sremmurd', 'Juicy J'],
#    'ranking': 97,
#    'song': ['Powerglide (song)'],
#    'songurl': ['/wiki/Powerglide_(song)'],
#    'titletext': '"Powerglide"',
#    'url': ['/wiki/Rae_Sremmurd', '/wiki/Juicy_J']},
#   {'band_singer': ['Dua Lipa'],
#    'ranking': 98,
#    'song': ['IDGAF (Dua Lipa song)'],
#    'songurl': ['/wiki/IDGAF_(Dua_Lipa_song)'],
#    'titletext': '"IDGAF"',
#    'url': ['/wiki/Dua_Lipa']},
#   {'band_singer': ['J Balvin', 'Willy William', 'Beyoncé'],
#    'ranking': 99,
#    'song': ['Mi Gente (J Balvin and Willy William song)'],
#    'songurl': ['/wiki/Mi_Gente_(J_Balvin_and_Willy_William_song)'],
#    'titletext': '"Mi Gente"',
#    'url': ['/wiki/J_Balvin', '/wiki/Willy_William', '/wiki/Beyonc%C3%A9']},
#   {'band_singer': ['Imagine Dragons'],
#    'ranking': 100,
#    'song': ['Believer (Imagine Dragons song)'],
#    'songurl': ['/wiki/Believer_(Imagine_Dragons_song)'],
#    'titletext': '"Believer"',
#    'url': ['/wiki/Imagine_Dragons']}]}

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %% [markdown]
# Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
#
# We will use this `flatframe` in the next question.

# %% [markdown]
# MULTIPLE WAYS TO DO THIS. HERE IS ONE. ANOTHER WAY IS TO PUT YEAR IN EVERY DICTIONARY IN THE LIST, GET RID OF TOP LEVEL DICT, AND THEN EXPAND OUT THE SINGERS AND SONGS (CARTESIAN PRODUCT) AS BELOW.

# %%
yeardict={}
for y in yearinfo.keys():
    yearlist=yearinfo[y] # get list of singles for year
    yearlist2=[]
    for singledict in yearlist:
        singers=singledict['band_singer']
        for i, singer in enumerate(singers):
            songs=singledict['song'] # generally one per single but maybe more
            for j, song in enumerate(songs): # now inside each singer song combination
                nd={}
                nd['band_singer'] = singer
                nd['url'] = singledict['url'][i]
                nd['song'] = song
                nd['songurl'] = singledict['songurl'][j]
                nd['ranking'] = singledict['ranking']
                yearlist2.append(nd)
    yeardict[y]=pd.DataFrame(yearlist2) # one for each year
yearspanel=pd.Panel.from_dict(yeardict, orient="minor") # stack dataframes into a panel
hierframe=yearspanel.to_frame() # flattening leads to a hierarchical index
hierframe.head()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:18: DeprecationWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#                        band_singer  ranking                                        song                                           songurl                          url
# major minor
# 0     1970       Simon & Garfunkel      1.0           Bridge Over Troubled Water (song)           /wiki/Bridge_Over_Troubled_Water_(song)    /wiki/Simon_%26_Garfunkel
#       1971         Three Dog Night      1.0          Joy to the World (Hoyt Axton song)          /wiki/Joy_to_the_World_(Hoyt_Axton_song)        /wiki/Three_Dog_Night
#       1972           Roberta Flack      1.0         The First Time Ever I Saw Your Face         /wiki/The_First_Time_Ever_I_Saw_Your_Face          /wiki/Roberta_Flack
#       1973   Tony Orlando and Dawn      1.0  Tie a Yellow Ribbon Round the Ole Oak Tree  /wiki/Tie_a_Yellow_Ribbon_Round_the_Ole_Oak_Tree  /wiki/Tony_Orlando_and_Dawn
#       1974        Barbra Streisand      1.0                      The Way We Were (song)                      /wiki/The_Way_We_Were_(song)       /wiki/Barbra_Streisand

# %%
flatframe = hierframe.reset_index()
flatframe.head()
# Out:
#    major minor            band_singer  ranking                                        song                                           songurl                          url
# 0      0  1970      Simon & Garfunkel      1.0           Bridge Over Troubled Water (song)           /wiki/Bridge_Over_Troubled_Water_(song)    /wiki/Simon_%26_Garfunkel
# 1      0  1971        Three Dog Night      1.0          Joy to the World (Hoyt Axton song)          /wiki/Joy_to_the_World_(Hoyt_Axton_song)        /wiki/Three_Dog_Night
# 2      0  1972          Roberta Flack      1.0         The First Time Ever I Saw Your Face         /wiki/The_First_Time_Ever_I_Saw_Your_Face          /wiki/Roberta_Flack
# 3      0  1973  Tony Orlando and Dawn      1.0  Tie a Yellow Ribbon Round the Ole Oak Tree  /wiki/Tie_a_Yellow_Ribbon_Round_the_Ole_Oak_Tree  /wiki/Tony_Orlando_and_Dawn
# 4      0  1974       Barbra Streisand      1.0                      The Way We Were (song)                      /wiki/The_Way_We_Were_(song)       /wiki/Barbra_Streisand

# %%
flatframe = flatframe.rename(columns={'minor':'year'})
del flatframe['major']
flatframe.head(8)
# Out:
#    year            band_singer  ranking                                        song                                           songurl                          url
# 0  1970      Simon & Garfunkel      1.0           Bridge Over Troubled Water (song)           /wiki/Bridge_Over_Troubled_Water_(song)    /wiki/Simon_%26_Garfunkel
# 1  1971        Three Dog Night      1.0          Joy to the World (Hoyt Axton song)          /wiki/Joy_to_the_World_(Hoyt_Axton_song)        /wiki/Three_Dog_Night
# 2  1972          Roberta Flack      1.0         The First Time Ever I Saw Your Face         /wiki/The_First_Time_Ever_I_Saw_Your_Face          /wiki/Roberta_Flack
# 3  1973  Tony Orlando and Dawn      1.0  Tie a Yellow Ribbon Round the Ole Oak Tree  /wiki/Tie_a_Yellow_Ribbon_Round_the_Ole_Oak_Tree  /wiki/Tony_Orlando_and_Dawn
# 4  1974       Barbra Streisand      1.0                      The Way We Were (song)                      /wiki/The_Way_We_Were_(song)       /wiki/Barbra_Streisand
# 5  1975     Captain & Tennille      1.0                  Love Will Keep Us Together                  /wiki/Love_Will_Keep_Us_Together   /wiki/Captain_%26_Tennille
# 6  1976           Wings (band)      1.0                            Silly Love Songs                            /wiki/Silly_Love_Songs           /wiki/Wings_(band)
# 7  1977            Rod Stewart      1.0      Tonight's the Night (Gonna Be Alright)    /wiki/Tonight%27s_the_Night_(Gonna_Be_Alright)            /wiki/Rod_Stewart

# %%
flatframe.dtypes
# Out:
# year            object
# band_singer     object
# ranking        float64
# song            object
# songurl         object
# url             object
# dtype: object

# %%
flatframe.year = flatframe.year.astype(int)
flatframe.dtypes
# Out:
# year             int64
# band_singer     object
# ranking        float64
# song            object
# songurl         object
# url             object
# dtype: object

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
prolific=flatframe.url.value_counts()
prolific[prolific > 25].plot(kind="barh");

# %%
# Out:
# 14

# %%
prolific
# Out:
# /wiki/Rihanna                        45
# /wiki/Madonna_(entertainer)          36
# /wiki/Lil_Wayne                      35
# /wiki/Mariah_Carey                   34
# /wiki/Drake_(musician)               33
# /wiki/Elton_John                     30
# /wiki/Janet_Jackson                  29
# /wiki/Ludacris                       29
# /wiki/R._Kelly                       28
# /wiki/Nicki_Minaj                    28
# /wiki/Michael_Jackson                27
# /wiki/Jay-Z                          26
# /wiki/Taylor_Swift                   26
# /wiki/Chris_Brown                    25
# /wiki/Kanye_West                     24
# /wiki/Justin_Timberlake              23
# /wiki/T-Pain                         23
# /wiki/Eminem                         22
# /wiki/Whitney_Houston                22
# /wiki/Maroon_5                       22
# /wiki/Pink_(singer)                  21
# /wiki/Stevie_Wonder                  20
# /wiki/Akon                           19
# /wiki/Katy_Perry                     19
# /wiki/T.I.                           18
# /wiki/Ne-Yo                          18
# /wiki/Justin_Bieber                  18
# /wiki/Kelly_Clarkson                 18
# /wiki/Snoop_Dogg                     18
# /wiki/Hall_%26_Oates                 18
#                                      ..
# /wiki/Amerie                          1
# /wiki/Cascada                         1
# /wiki/Clarence_Carter                 1
# /wiki/Trapt                           1
# /wiki/Citizen_King                    1
# /wiki/Westlife                        1
# /wiki/Michael_Sembello                1
# /wiki/Amil_(rapper)                   1
# /wiki/Paul_Wall                       1
# /wiki/Becky_G                         1
# /wiki/Brenda_K._Starr                 1
# /wiki/The_Delfonics                   1
# /wiki/Next_(group)                    1
# /wiki/Tweet_(singer)                  1
# /wiki/Sons_of_Funk                    1
# /wiki/Quincy_Jones                    1
# /wiki/Loleatta_Holloway               1
# /wiki/Terri_Gibbs                     1
# /wiki/Jet_(band)                      1
# /wiki/Jonathan_Edwards_(musician)     1
# /wiki/Bobby_Vinton                    1
# /wiki/Samantha_Sang                   1
# /wiki/Erick_Sermon                    1
# /wiki/The_First_Class                 1
# /wiki/Houston_(singer)                1
# /wiki/Cassidy_(rapper)                1
# /wiki/Amanda_Perez                    1
# /wiki/Bazzi_(singer)                  1
# /wiki/Cher_Lloyd                      1
# /wiki/M_(band)                        1
# Name: url, Length: 2070, dtype: int64

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
scores = flatframe.groupby('url').apply(lambda v: np.sum(101 - v['ranking']))
scores= scores.sort_values(ascending=False)
scores[:5].plot(kind="barh");

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %%
scores
# Out:
# url
# /wiki/Rihanna                             2760.0
# /wiki/Mariah_Carey                        2290.0
# /wiki/Drake_(musician)                    1969.0
# /wiki/Madonna_(entertainer)               1888.0
# /wiki/Janet_Jackson                       1886.0
# /wiki/Elton_John                          1775.0
# /wiki/Lil_Wayne                           1723.0
# /wiki/Whitney_Houston                     1491.0
# /wiki/Michael_Jackson                     1453.0
# /wiki/Taylor_Swift                        1438.0
# /wiki/Ludacris                            1429.0
# /wiki/Jay-Z                               1417.0
# /wiki/Maroon_5                            1353.0
# /wiki/Justin_Timberlake                   1351.0
# /wiki/Bruno_Mars                          1342.0
# /wiki/Nicki_Minaj                         1337.0
# /wiki/Kanye_West                          1322.0
# /wiki/Katy_Perry                          1319.0
# /wiki/Pink_(singer)                       1226.0
# /wiki/Chris_Brown                         1150.0
# /wiki/Nelly                               1134.0
# /wiki/Stevie_Wonder                       1131.0
# /wiki/Justin_Bieber                       1106.0
# /wiki/Akon                                1086.0
# /wiki/Sean_Combs                          1068.0
# /wiki/R._Kelly                            1023.0
# /wiki/Alicia_Keys                         1010.0
# /wiki/Eminem                               991.0
# /wiki/Hall_%26_Oates                       984.0
# /wiki/50_Cent                              982.0
#                                            ...
# /wiki/Bravehearts                            3.0
# /wiki/Albert_Hammond                         3.0
# /wiki/Samantha_Mumba                         3.0
# /wiki/B.B._King                              3.0
# /wiki/Blackbear_(musician)                   3.0
# /wiki/Robin_Zander                           3.0
# /wiki/Grace_Potter_and_the_Nocturnals        3.0
# /wiki/Beastie_Boys                           3.0
# /wiki/Bachman%E2%80%93Turner_Overdrive       3.0
# /wiki/Ron_Browz                              3.0
# /wiki/Pseudo_Echo                            2.0
# /wiki/Fancy_(band)                           2.0
# /wiki/John_Michael_Montgomery                2.0
# /wiki/Taylor_Hicks                           2.0
# /wiki/Mellow_Man_Ace                         2.0
# /wiki/George_Clinton_(musician)              2.0
# /wiki/London_Symphony_Orchestra              2.0
# /wiki/Disciples_(production_team)            1.0
# /wiki/Teddy_Geiger                           1.0
# /wiki/C.J._%26_Company                       1.0
# /wiki/Tay_Dizm                               1.0
# /wiki/2_Pistols                              1.0
# /wiki/Jerrod_Niemann                         1.0
# /wiki/Disco-Tex_and_the_Sex-O-Lettes         1.0
# /wiki/TQ_(singer)                            1.0
# /wiki/Perry_Como                             1.0
# /wiki/Floetry                                1.0
# /wiki/Bun_B                                  1.0
# /wiki/Fuel_(band)                            1.0
# /wiki/Mary_Mary                              1.0
# Length: 2070, dtype: float64

# %%
scores[40:50]
# Out:
# url
# /wiki/Snoop_Dogg            885.0
# /wiki/Kelly_Clarkson        877.0
# /wiki/Phil_Collins          872.0
# /wiki/Lady_Gaga             860.0
# /wiki/Bee_Gees              851.0
# /wiki/Olivia_Newton-John    842.0
# /wiki/Missy_Elliott         838.0
# /wiki/Flo_Rida              825.0
# /wiki/The_Weeknd            801.0
# /wiki/Timbaland             754.0
# dtype: float64

# %% [markdown]
# It seems Lil Wayne appeared in the top 100 many many times (31 times) but got beat out in terms of rankings by both Usher and Mariah Carey. Now we're in a position to answer the question that was posed in the beginning of this assignment -- who is a *better* singer, Mariah Carey or Rihanna? Well, it turns out Rihanna is more *prolific* by our definition, by quite a lot. So based on our analysis we have to give the title to Rihanna.

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %%
#hi

# %%
#hi

# %%
#use

# %%
#hi

# %%
flatframe.head()
# Out:
#       year               band_singer  ranking                               song                                  songurl                             url
# 0     1970         Simon & Garfunkel      1.0  Bridge Over Troubled Water (song)  /wiki/Bridge_Over_Troubled_Water_(song)       /wiki/Simon_%26_Garfunkel
# 783   1970              Neil Diamond     17.0                    Cracklin' Rosie                  /wiki/Cracklin%27_Rosie              /wiki/Neil_Diamond
# 4219  1970               The Pipkins     86.0              Gimme Dat Ding (song)              /wiki/Gimme_Dat_Ding_(song)               /wiki/The_Pipkins
# 832   1970     Tony Orlando and Dawn     18.0                     Candida (song)                     /wiki/Candida_(song)     /wiki/Tony_Orlando_and_Dawn
# 4171  1970  The Ides of March (band)     85.0                     Vehicle (song)                     /wiki/Vehicle_(song)  /wiki/The_Ides_of_March_(band)

# %%
#gi

# %%
#hi

# %%
#hi
